# %% [markdown]
# # Projet: Analyse des données et pre-processing
#
# Eduardo Cobos Fernandez, Sipan Bareyan Jeremy Rakotorinira, Amine Berrahma
#
# Analyse et réduction des bias en Machine Learning
#
# Dans ce notebook on va ...

# %% [markdown]
# # 0 - Introduction
#
# **intro mi-projet edu :**
#
# Les modèles de prédiction sont de plus en plus utilisés dans le domaine médical, notamment pour l’aide au diagnostic à partir de données patients et d’imagerie médicale. Toutefois, ces modèles peuvent hériter de biais présents dans les données utilisées pour leur apprentissage, ce qui rend nécessaire une analyse préalable de ces données.
#
# Ce mi-projet s’appuie sur le dataset Chest X-ray NIH14 (https://www.kaggle.com/datasets/nih-chest-xrays/data), qui contient des radiographies thoraciques ainsi que des métadonnées associées aux patients, telles que l’âge, le genre et les pathologies diagnostiquées. Pour cette étape intermédiaire du projet, l’analyse se limite aux métadonnées, les images n’étant pas considérées. Un sous-ensemble de 15.000 radiographies est utilisé.
#
# L’objectif de ce travail est d’analyser les métadonnées afin d’identifier d’éventuels biais liés à des attributs sensibles, puis d’appliquer une méthode de pré-processing pour réduire ces biais et construire un dataset transformé. Ce travail constitue une étape préparatoire au projet final, dans lequel l’impact du pré-processing sur un modèle basé sur les images sera étudié.
#
#
# **intro mi-projet amine:**
#
# L’intelligence artificielle joue un rôle important dans le domaine médical, notamment dans l’analyse d’images radiologiques. Les modèles de deep learning appliqués aux radiographies thoraciques peuvent assister les médecins dans le diagnostic de diverses maladies. Toutefois, ces systèmes peuvent reproduire ou amplifier des biais présents dans les données, ce qui peut conduire à des performances inéquitables selon certains groupes de patients.
#
# Le cas d’usage étudié dans ce projet repose sur un sous-ensemble du dataset NIH Chest X-ray, composé de métadonnées associées à des radiographies thoraciques. Ce dataset contient des informations diverses (âge, genre...etc) ainsi que des annotations médicales indiquant la présence ou l’absence de maladies.
#
# L’objectif principal de ce projet est d’identifier et d’analyser les biais potentiels présents dans ces données, en particulier en lien avec des attributs sensibles tels que le genre et l’âge. Pour cela, dans un premier temps une analyse descriptive est réalisée afin d’examiner la distribution des maladies selon ces groupes.
#
# Dans un second temps, des métriques d’équité telles que la Statistical Parity Difference (SPD) et le Disparate Impact (DI) sont utilisées pour quantifier les déséquilibres observés.
# Enfin, une méthode de mitigation par preprocessing, basée sur l’algorithme Reweighing, est appliquée afin de réduire ces biais et produire un dataset transformé plus équitable.

# %% [markdown]
# # Chargement des données
#
# Les métadonnées du dataset Chest X-ray NIH14 sont chargées à partir du fichier fourni pour le projet. Ce fichier contient les informations associées à un sous-ensemble de 15 000 patients. (à modifier??)

# %%
from pathlib import Path

DATADIR= Path('Cobos_Fernandez_Eduardo')

# %%
### RUN ONLY ON COLAB: Put the zip file of the data in your google drive in a folder called "fairness"
confirm = input("Are you sure you are running this on Colab ? Confirm with 'y'")
if confirm != 'y':
    raise ValueError("You must confirm you are running on Colab")
# Only for Google Colab
from google.colab import drive
drive.mount('/content/drive')


# Only for Google Colab
import sys

# In your google drive, create a folder for the Fairness project
# (called here 'coursFairness')
# Copy in this folder the python file train_classifieur.py
# Copy in this folder your zipped data folder (called here 'YOUR_NAME.zip')

# Path to the folder containing the python file
drive_module_path = "drive/MyDrive/fairness" #modifié pour que ça marche sur ma machine
sys.path.append(drive_module_path)

# Verify the path was added
print(sys.path[-1])

project_folder = Path(drive_module_path)
zip_filename = "Cobos_Fernandez_Eduardo.zip"
zip_path = project_folder / zip_filename

if not project_folder.exists() or not zip_path.exists():
  print("Colab Config failed")
  print("Make sure you have the folder fairness folder in your google drive, and it contains the zip file named Cobos_Fernandez_Eduardo.zip")
  raise ValueError("Colab Config failed")


# !cp /content/drive/MyDrive/fairness/Cobos_Fernandez_Eduardo.zip /content/
# !mkdir -p /content/DATA/
# !unzip -o Cobos_Fernandez_Eduardo.zip -d /content/DATA/

# !pip install pandas\
  numpy\
  torchvision\
  torch\
  torchmetrics\
  tensorboard\
  pillow\
  lightning\
  matplotlib\
  scikit_learn\
  ipykernel \
  fairlearn \
  plotly \
  nbformat \
  aif360["inFairness"] \
  aif360['AdversarialDebiasing'] \
  causal-learn \
  BlackBoxAuditing \
  cvxpy \
  dice-ml \
  lime \

DATADIR = Path("/content/DATA")
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   inflating: /content/DATA/valid/sain/00011255_009.png
#   inflating: /content/DATA/valid/sain/00019878_001.png
#   inflating: /content/DATA/valid/sain/00011237_095.png
#   inflating: /content/DATA/valid/sain/00017158_013.png
#   inflating: /content/DATA/valid/sain/00009436_007.png
#   inflating: /content/DATA/valid/sain/00010120_012.png
#   inflating: /content/DATA/valid/sain/00009001_000.png
#   inflating: /content/DATA/valid/sain/00028433_004.png
#   inflating: /content/DATA/valid/sain/00011237_096.png
#   inflating: /content/DATA/valid/sain/00008561_014.png
#   inflating: /content/DATA/valid/sain/00003724_000.png
#   inflating: /content/DATA/valid/sain/00020269_001.png
#   inflating: /content/DATA/valid/sain/00001084_001.png
#   inflating: /content/DATA/valid/sain/00010120_005.png
#   inflating: /content/DATA/valid/sain/00007321_012.png
#   inflating: /content/DATA/valid/sain/00010722_001.png
#   inflating: /content/DATA/valid/sain/00020018_003.png
#   inflating: /content/DATA/valid/sain/00017158_012.png
#   inflating: /content/DATA/valid/sain/00011255_008.png
#   inflating: /content/DATA/valid/sain/00008039_003.png
#   inflating: /content/DATA/valid/sain/00001348_000.png
#   inflating: /content/DATA/valid/sain/00029880_005.png
#   inflating: /content/DATA/valid/sain/00017158_046.png
#   inflating: /content/DATA/valid/sain/00008581_000.png
#   inflating: /content/DATA/valid/sain/00019592_003.png
#   inflating: /content/DATA/valid/sain/00010120_000.png
#   inflating: /content/DATA/valid/sain/00011237_023.png
#   inflating: /content/DATA/valid/sain/00004429_000.png
#   inflating: /content/DATA/valid/sain/00014476_000.png
#   inflating: /content/DATA/valid/sain/00028856_004.png
#   inflating: /content/DATA/valid/sain/00003211_002.png
#   inflating: /content/DATA/valid/sain/00001248_008.png
#   inflating: /content/DATA/valid/sain/00018527_000.png
#   inflating: /content/DATA/valid/sain/00028403_000.png
#   inflating: /content/DATA/valid/sain/00007321_002.png
#   inflating: /content/DATA/valid/sain/00015058_009.png
#   inflating: /content/DATA/valid/sain/00001568_001.png
#   inflating: /content/DATA/valid/sain/00026428_001.png
#   inflating: /content/DATA/valid/sain/00007120_001.png
#   inflating: /content/DATA/valid/sain/00022888_005.png
#   inflating: /content/DATA/valid/sain/00003504_002.png
#   inflating: /content/DATA/valid/sain/00029202_001.png
#   inflating: /content/DATA/valid/sain/00015657_000.png
#   inflating: /content/DATA/valid/sain/00017158_016.png
#   inflating: /content/DATA/valid/sain/00020530_000.png
#   inflating: /content/DATA/valid/sain/00014848_001.png
#   inflating: /content/DATA/valid/sain/00009001_006.png
#   inflating: /content/DATA/valid/sain/00005058_000.png
#   inflating: /content/DATA/valid/sain/00015826_011.png
#   inflating: /content/DATA/valid/sain/00007648_000.png
#   inflating: /content/DATA/valid/sain/00019592_004.png
#   inflating: /content/DATA/valid/sain/00015187_002.png
#   inflating: /content/DATA/valid/sain/00017158_031.png
#   inflating: /content/DATA/valid/sain/00011237_052.png
#   inflating: /content/DATA/valid/sain/00003362_000.png
#   inflating: /content/DATA/valid/sain/00022802_000.png
#   inflating: /content/DATA/valid/sain/00000541_001.png
#   inflating: /content/DATA/valid/sain/00028365_000.png
#   inflating: /content/DATA/valid/sain/00015826_034.png
#   inflating: /content/DATA/valid/sain/00015995_005.png
#   inflating: /content/DATA/valid/sain/00024573_000.png
#   inflating: /content/DATA/valid/sain/00000541_003.png
#   inflating: /content/DATA/valid/sain/00006070_004.png
#   inflating: /content/DATA/valid/sain/00008263_001.png
#   inflating: /content/DATA/valid/sain/00011237_035.png
#   inflating: /content/DATA/valid/sain/00015058_016.png
#   inflating: /content/DATA/valid/sain/00001068_000.png
#   inflating: /content/DATA/valid/sain/00015826_025.png
#   inflating: /content/DATA/valid/sain/00023075_031.png
#   inflating: /content/DATA/valid/sain/00004404_005.png
#   inflating: /content/DATA/valid/sain/00020634_001.png
#   inflating: /content/DATA/valid/sain/00015058_010.png
#   inflating: /content/DATA/valid/sain/00001568_005.png
#   inflating: /content/DATA/valid/sain/00008345_001.png
#   inflating: /content/DATA/valid/sain/00002425_005.png
#   inflating: /content/DATA/valid/sain/00025608_001.png
#   inflating: /content/DATA/valid/sain/00017408_000.png
#   inflating: /content/DATA/valid/sain/00007913_000.png
#   inflating: /content/DATA/valid/sain/00028433_006.png
#   inflating: /content/DATA/valid/sain/00015058_005.png
#   inflating: /content/DATA/valid/sain/00020662_001.png
#   inflating: /content/DATA/valid/sain/00011237_030.png
#   inflating: /content/DATA/valid/sain/00007057_001.png
#   inflating: /content/DATA/valid/sain/00010993_000.png
#   inflating: /content/DATA/valid/sain/00001068_003.png
#   inflating: /content/DATA/valid/sain/00024162_000.png
#   inflating: /content/DATA/valid/sain/00003362_005.png
#   inflating: /content/DATA/valid/sain/00015826_030.png
#   inflating: /content/DATA/valid/sain/00025041_000.png
#   inflating: /content/DATA/valid/sain/00006070_007.png
#   inflating: /content/DATA/valid/sain/00011237_101.png
#   inflating: /content/DATA/valid/sain/00015826_022.png
#   inflating: /content/DATA/valid/sain/00000312_000.png
#   inflating: /content/DATA/valid/sain/00006070_008.png
#   inflating: /content/DATA/valid/sain/00013312_007.png
#   inflating: /content/DATA/valid/sain/00022269_001.png
#   inflating: /content/DATA/valid/sain/00023385_000.png
#   inflating: /content/DATA/valid/sain/00003212_000.png
#   inflating: /content/DATA/valid/sain/00021048_001.png
#   inflating: /content/DATA/valid/sain/00030304_000.png
#   inflating: /content/DATA/valid/sain/00009727_009.png
#   inflating: /content/DATA/valid/sain/00001248_001.png
#   inflating: /content/DATA/valid/sain/00015058_012.png
#   inflating: /content/DATA/valid/sain/00017158_044.png
#   inflating: /content/DATA/valid/sain/00027958_000.png
#   inflating: /content/DATA/valid/sain/00028433_007.png
#   inflating: /content/DATA/valid/sain/00030670_000.png
#   inflating: /content/DATA/valid/sain/00008039_000.png
#   inflating: /content/DATA/valid/sain/00004531_000.png
#   inflating: /content/DATA/valid/sain/00010120_020.png
#   inflating: /content/DATA/valid/sain/00009727_008.png
#   inflating: /content/DATA/valid/sain/00011237_107.png
#   inflating: /content/DATA/valid/sain/00001826_002.png
#   inflating: /content/DATA/valid/sain/00028994_000.png
#   inflating: /content/DATA/valid/sain/00017158_048.png
#   inflating: /content/DATA/valid/sain/00000567_000.png
#   inflating: /content/DATA/valid/sain/00016666_000.png
#   inflating: /content/DATA/valid/sain/00008581_001.png
#   inflating: /content/DATA/valid/sain/00010722_003.png
#   inflating: /content/DATA/valid/sain/00017158_017.png
#   inflating: /content/DATA/valid/sain/00009662_000.png
#   inflating: /content/DATA/valid/sain/00015995_002.png
#   inflating: /content/DATA/valid/sain/00018513_001.png
#   inflating: /content/DATA/valid/sain/00010120_004.png
#   inflating: /content/DATA/valid/sain/00022269_002.png
#   inflating: /content/DATA/valid/sain/00018513_000.png
#   inflating: /content/DATA/valid/sain/00014337_003.png
#   inflating: /content/DATA/valid/sain/00006829_001.png
#   inflating: /content/DATA/valid/sain/00003212_001.png
#   inflating: /content/DATA/valid/sain/00015995_004.png
#   inflating: /content/DATA/valid/sain/00011255_002.png
#   inflating: /content/DATA/valid/sain/00010722_007.png
#   inflating: /content/DATA/valid/sain/00007572_000.png
#   inflating: /content/DATA/valid/sain/00024125_000.png
#   inflating: /content/DATA/valid/sain/00009727_024.png
#   inflating: /content/DATA/valid/sain/00020411_000.png
#   inflating: /content/DATA/valid/sain/00022764_014.png
#   inflating: /content/DATA/valid/sain/00013312_002.png
#   inflating: /content/DATA/valid/sain/00011213_001.png
#   inflating: /content/DATA/valid/sain/00015826_015.png
#   inflating: /content/DATA/valid/sain/00023893_000.png
#   inflating: /content/DATA/valid/sain/00004404_003.png
#   inflating: /content/DATA/valid/sain/00017158_023.png
#   inflating: /content/DATA/valid/sain/00012641_003.png
#   inflating: /content/DATA/valid/sain/00011237_078.png
#   inflating: /content/DATA/valid/sain/00003504_001.png
#   inflating: /content/DATA/valid/sain/00012256_000.png
#   inflating: /content/DATA/valid/sain/00026259_002.png
#   inflating: /content/DATA/valid/sain/00023075_029.png
#   inflating: /content/DATA/valid/sain/00011237_007.png
#   inflating: /content/DATA/valid/sain/00006249_004.png
#   inflating: /content/DATA/valid/sain/00001503_000.png
#   inflating: /content/DATA/valid/sain/00018665_004.png
#   inflating: /content/DATA/valid/sain/00002425_006.png
#   inflating: /content/DATA/valid/sain/00022395_000.png
#   inflating: /content/DATA/valid/sain/00006775_001.png
#   inflating: /content/DATA/valid/sain/00013564_002.png
#   inflating: /content/DATA/valid/sain/00017158_039.png
#   inflating: /content/DATA/valid/sain/00008561_010.png
#   inflating: /content/DATA/valid/sain/00008125_001.png
#   inflating: /content/DATA/valid/sain/00023075_025.png
#   inflating: /content/DATA/valid/sain/00001568_004.png
#   inflating: /content/DATA/valid/sain/00015995_008.png
#   inflating: /content/DATA/valid/sain/00012641_004.png
#   inflating: /content/DATA/valid/sain/00017934_001.png
#   inflating: /content/DATA/valid/sain/00017158_021.png
#   inflating: /content/DATA/valid/sain/00001507_002.png
#   inflating: /content/DATA/valid/sain/00012238_000.png
#   inflating: /content/DATA/valid/sain/00005058_005.png
#   inflating: /content/DATA/valid/sain/00016001_001.png
#   inflating: /content/DATA/valid/sain/00026524_008.png
#   inflating: /content/DATA/valid/sain/00023075_019.png
#   inflating: /content/DATA/valid/sain/00006823_002.png
#   inflating: /content/DATA/valid/sain/00026408_000.png
#   inflating: /content/DATA/valid/sain/00008263_000.png
#   inflating: /content/DATA/valid/sain/00025381_009.png
#   inflating: /content/DATA/valid/sain/00008345_005.png
#   inflating: /content/DATA/valid/sain/00002793_002.png
#   inflating: /content/DATA/valid/sain/00023498_007.png
#   inflating: /content/DATA/valid/sain/00024710_000.png
#   inflating: /content/DATA/valid/sain/00006823_000.png
#   inflating: /content/DATA/valid/sain/00020596_000.png
#   inflating: /content/DATA/valid/sain/00023075_028.png
#   inflating: /content/DATA/valid/sain/00008561_004.png
#   inflating: /content/DATA/valid/sain/00015116_000.png
#   inflating: /content/DATA/valid/sain/00016188_000.png
#   inflating: /content/DATA/valid/sain/00011237_084.png
#   inflating: /content/DATA/valid/sain/00009727_028.png
#   inflating: /content/DATA/valid/sain/00000312_002.png
#   inflating: /content/DATA/valid/sain/00007638_001.png
#   inflating: /content/DATA/valid/sain/00009727_019.png
#   inflating: /content/DATA/valid/sain/00021052_000.png
#   inflating: /content/DATA/valid/sain/00011237_031.png
#   inflating: /content/DATA/valid/sain/00008169_000.png
#   inflating: /content/DATA/valid/sain/00011237_004.png
#   inflating: /content/DATA/valid/sain/00011237_034.png
#   inflating: /content/DATA/valid/sain/00017336_001.png
#   inflating: /content/DATA/valid/sain/00009436_004.png
#   inflating: /content/DATA/valid/sain/00007541_000.png
#   inflating: /content/DATA/valid/sain/00009436_005.png
#   inflating: /content/DATA/valid/sain/00001659_000.png
#   inflating: /content/DATA/valid/sain/00013123_000.png
#   inflating: /content/DATA/valid/sain/00004404_009.png
#   inflating: /content/DATA/valid/sain/00028549_010.png
#   inflating: /content/DATA/valid/sain/00007072_000.png
#   inflating: /content/DATA/valid/sain/00002387_000.png
#   inflating: /content/DATA/valid/sain/00017158_014.png
#   inflating: /content/DATA/valid/sain/00021274_002.png
#   inflating: /content/DATA/valid/sain/00013564_001.png
#   inflating: /content/DATA/valid/sain/00017158_041.png
#   inflating: /content/DATA/valid/sain/00026389_003.png
#   inflating: /content/DATA/valid/sain/00001248_031.png
#   inflating: /content/DATA/valid/sain/00004206_000.png
#   inflating: /content/DATA/valid/sain/00016853_000.png
#   inflating: /content/DATA/valid/sain/00010120_002.png
#   inflating: /content/DATA/valid/sain/00007638_003.png
#   inflating: /content/DATA/valid/sain/00020018_005.png
#   inflating: /content/DATA/valid/sain/00015826_004.png
#   inflating: /content/DATA/valid/sain/00011237_043.png
#   inflating: /content/DATA/valid/sain/00004404_002.png
#   inflating: /content/DATA/valid/sain/00017037_000.png
#   inflating: /content/DATA/valid/sain/00020662_000.png
#   inflating: /content/DATA/valid/sain/00001288_000.png
#   inflating: /content/DATA/valid/sain/00022764_008.png
#   inflating: /content/DATA/valid/sain/00013478_000.png
#   inflating: /content/DATA/valid/sain/00001773_000.png
#   inflating: /content/DATA/valid/sain/00017158_007.png
#   inflating: /content/DATA/valid/sain/00017594_001.png
#   inflating: /content/DATA/valid/sain/00009436_006.png
#   inflating: /content/DATA/valid/sain/00006070_003.png
#   inflating: /content/DATA/valid/sain/00026446_000.png
#   inflating: /content/DATA/valid/sain/00020546_000.png
#   inflating: /content/DATA/valid/sain/00020755_000.png
#   inflating: /content/DATA/valid/sain/00007321_001.png
#   inflating: /content/DATA/valid/sain/00002793_005.png
#   inflating: /content/DATA/valid/sain/00018496_004.png
#   inflating: /content/DATA/valid/sain/00002793_000.png
#   inflating: /content/DATA/valid/sain/00014003_000.png
#   inflating: /content/DATA/valid/sain/00019592_009.png
#   inflating: /content/DATA/valid/sain/00019680_003.png
#   inflating: /content/DATA/valid/sain/00029477_001.png
#   inflating: /content/DATA/valid/sain/00002793_003.png
#   inflating: /content/DATA/valid/sain/00017158_049.png
#   inflating: /content/DATA/valid/sain/00015058_004.png
#   inflating: /content/DATA/valid/sain/00019350_000.png
#   inflating: /content/DATA/valid/sain/00003345_000.png
#   inflating: /content/DATA/valid/sain/00000923_000.png
#   inflating: /content/DATA/valid/sain/00023749_000.png
#   inflating: /content/DATA/valid/sain/00011237_012.png
#   inflating: /content/DATA/valid/sain/00004749_002.png
#   inflating: /content/DATA/valid/sain/00014485_000.png
#   inflating: /content/DATA/valid/sain/00000619_002.png
#   inflating: /content/DATA/valid/sain/00000541_002.png
#   inflating: /content/DATA/valid/sain/00011237_037.png
#   inflating: /content/DATA/valid/sain/00009100_001.png
#   inflating: /content/DATA/valid/sain/00018268_000.png
#   inflating: /content/DATA/valid/sain/00011255_005.png
#   inflating: /content/DATA/valid/sain/00017158_033.png
#   inflating: /content/DATA/valid/sain/00015826_003.png
#   inflating: /content/DATA/valid/sain/00010592_005.png
#   inflating: /content/DATA/valid/sain/00015826_018.png
#   inflating: /content/DATA/valid/sain/00005058_001.png
#   inflating: /content/DATA/valid/sain/00001248_037.png
#   inflating: /content/DATA/valid/sain/00001568_003.png
#   inflating: /content/DATA/valid/sain/00015826_012.png
#   inflating: /content/DATA/valid/sain/00017158_024.png
#   inflating: /content/DATA/valid/sain/00005058_003.png
#   inflating: /content/DATA/valid/sain/00003211_001.png
#   inflating: /content/DATA/valid/sain/00001084_000.png
#   inflating: /content/DATA/valid/sain/00017158_034.png
#   inflating: /content/DATA/valid/sain/00003211_005.png
#   inflating: /content/DATA/valid/sain/00017158_009.png
#   inflating: /content/DATA/valid/sain/00000386_000.png
#   inflating: /content/DATA/valid/sain/00022087_000.png
#   inflating: /content/DATA/valid/sain/00023075_040.png
#   inflating: /content/DATA/valid/sain/00030803_000.png
#   inflating: /content/DATA/valid/sain/00009727_025.png
#   inflating: /content/DATA/valid/sain/00002425_001.png
#   inflating: /content/DATA/valid/sain/00026284_000.png
#   inflating: /content/DATA/valid/sain/00012195_000.png
#   inflating: /content/DATA/valid/sain/00011237_025.png
#   inflating: /content/DATA/valid/sain/00006823_001.png
#   inflating: /content/DATA/valid/sain/00007831_000.png
#   inflating: /content/DATA/valid/sain/00003062_010.png
#   inflating: /content/DATA/valid/sain/00021921_000.png
#   inflating: /content/DATA/valid/sain/00011237_077.png
#   inflating: /content/DATA/valid/sain/00023498_001.png
#   inflating: /content/DATA/valid/sain/00007638_000.png
#   inflating: /content/DATA/valid/sain/00015058_022.png
#   inflating: /content/DATA/valid/sain/00018392_000.png
#   inflating: /content/DATA/valid/sain/00009001_001.png
#   inflating: /content/DATA/valid/sain/00017934_000.png
#   inflating: /content/DATA/valid/sain/00011255_006.png
#   inflating: /content/DATA/valid/sain/00011237_017.png
#   inflating: /content/DATA/valid/sain/00000589_000.png
#   inflating: /content/DATA/valid/sain/00023388_000.png
#   inflating: /content/DATA/valid/sain/00022764_005.png
#   inflating: /content/DATA/valid/sain/00010722_006.png
#   inflating: /content/DATA/valid/sain/00009727_014.png
#   inflating: /content/DATA/valid/sain/00018506_000.png
#   inflating: /content/DATA/valid/sain/00000541_000.png
#   inflating: /content/DATA/valid/sain/00025381_007.png
#   inflating: /content/DATA/valid/sain/00026061_000.png
#   inflating: /content/DATA/valid/sain/00026392_002.png
#   inflating: /content/DATA/valid/sain/00008207_000.png
#   inflating: /content/DATA/valid/sain/00001347_002.png
#   inflating: /content/DATA/valid/sain/00001568_006.png
#   inflating: /content/DATA/valid/sain/00020893_000.png
#   inflating: /content/DATA/valid/sain/00012238_001.png
#   inflating: /content/DATA/valid/sain/00006083_000.png
#   inflating: /content/DATA/valid/sain/00022888_004.png
#   inflating: /content/DATA/valid/sain/00006533_000.png
#   inflating: /content/DATA/valid/sain/00023075_010.png
#   inflating: /content/DATA/valid/sain/00004531_002.png
#   inflating: /content/DATA/valid/sain/00017158_019.png
#   inflating: /content/DATA/valid/sain/00025381_004.png
#   inflating: /content/DATA/valid/sain/00000888_001.png
#   inflating: /content/DATA/valid/sain/00006369_000.png
#   inflating: /content/DATA/valid/sain/00028433_016.png
#   inflating: /content/DATA/valid/sain/00019680_008.png
#   inflating: /content/DATA/valid/sain/00026524_002.png
#   inflating: /content/DATA/valid/sain/00011237_028.png
#   inflating: /content/DATA/valid/sain/00010305_000.png
#   inflating: /content/DATA/valid/sain/00013123_004.png
#   inflating: /content/DATA/valid/sain/00017158_037.png
#   inflating: /content/DATA/valid/sain/00028433_009.png
#   inflating: /content/DATA/valid/sain/00013123_002.png
#   inflating: /content/DATA/valid/sain/00013123_005.png
#   inflating: /content/DATA/valid/sain/00017158_025.png
#   inflating: /content/DATA/valid/sain/00015187_003.png
#   inflating: /content/DATA/valid/sain/00015058_021.png
#   inflating: /content/DATA/valid/sain/00021609_000.png
#   inflating: /content/DATA/valid/sain/00023590_000.png
#   inflating: /content/DATA/valid/sain/00018548_004.png
#   inflating: /content/DATA/valid/sain/00015826_016.png
#   inflating: /content/DATA/valid/sain/00003211_003.png
#   inflating: /content/DATA/valid/sain/00004404_001.png
#   inflating: /content/DATA/valid/sain/00023498_008.png
#   inflating: /content/DATA/valid/sain/00019992_001.png
#   inflating: /content/DATA/valid/sain/00009727_003.png
#   inflating: /content/DATA/valid/sain/00017158_047.png
#   inflating: /content/DATA/valid/sain/00019508_000.png
#   inflating: /content/DATA/valid/sain/00021274_014.png
#   inflating: /content/DATA/valid/sain/00009436_001.png
#   inflating: /content/DATA/valid/sain/00012238_005.png
#   inflating: /content/DATA/valid/sain/00008705_001.png
#   inflating: /content/DATA/valid/sain/00006091_001.png
#   inflating: /content/DATA/valid/sain/00011847_001.png
#   inflating: /content/DATA/valid/sain/00007321_011.png
#   inflating: /content/DATA/valid/sain/00010120_011.png
#   inflating: /content/DATA/valid/sain/00003362_002.png
#   inflating: /content/DATA/valid/sain/00002793_004.png
#   inflating: /content/DATA/valid/sain/00010722_004.png
#   inflating: /content/DATA/valid/sain/00028549_004.png
#   inflating: /content/DATA/valid/sain/00000619_000.png
#   inflating: /content/DATA/valid/sain/00027176_000.png
#   inflating: /content/DATA/valid/sain/00006249_005.png
#   inflating: /content/DATA/valid/sain/00007483_000.png
#   inflating: /content/DATA/valid/sain/00017158_008.png
#   inflating: /content/DATA/valid/sain/00001507_000.png
#   inflating: /content/DATA/valid/sain/00017158_015.png
#   inflating: /content/DATA/valid/sain/00005058_002.png
#   inflating: /content/DATA/valid/sain/00017158_002.png
#   inflating: /content/DATA/valid/sain/00004838_000.png
#   inflating: /content/DATA/valid/sain/00000174_003.png
#   inflating: /content/DATA/valid/sain/00022681_000.png
#   inflating: /content/DATA/valid/sain/00017594_002.png
#   inflating: /content/DATA/valid/sain/00021274_003.png
#   inflating: /content/DATA/valid/sain/00023075_037.png
#   inflating: /content/DATA/valid/sain/00001568_002.png
#   inflating: /content/DATA/valid/sain/00026519_000.png
#   inflating: /content/DATA/valid/sain/00028549_003.png
#   inflating: /content/DATA/valid/sain/00028365_001.png
#   inflating: /content/DATA/valid/sain/00003062_009.png
#   inflating: /content/DATA/valid/sain/00010397_000.png
#   inflating: /content/DATA/valid/sain/00009727_034.png
#   inflating: /content/DATA/valid/sain/00026408_001.png
#   inflating: /content/DATA/valid/sain/00021609_005.png
#   inflating: /content/DATA/valid/sain/00011237_115.png
#   inflating: /content/DATA/valid/sain/00008561_003.png
#   inflating: /content/DATA/valid/sain/00029880_010.png
#   inflating: /content/DATA/valid/sain/00001248_027.png
#   inflating: /content/DATA/valid/sain/00003504_000.png
#   inflating: /content/DATA/valid/sain/00004749_000.png
#   inflating: /content/DATA/valid/sain/00006249_002.png
#   inflating: /content/DATA/valid/sain/00023075_043.png
#   inflating: /content/DATA/valid/sain/00002699_001.png
#   inflating: /content/DATA/valid/sain/00014337_002.png
#   inflating: /content/DATA/valid/sain/00003920_000.png
#   inflating: /content/DATA/valid/sain/00028181_000.png
#   inflating: /content/DATA/valid/sain/00012238_007.png
#   inflating: /content/DATA/valid/sain/00004404_007.png
#   inflating: /content/DATA/valid/sain/00019680_009.png
#   inflating: /content/DATA/valid/sain/00017158_006.png
#   inflating: /content/DATA/valid/sain/00013123_011.png
#   inflating: /content/DATA/valid/sain/00021462_000.png
#   inflating: /content/DATA/valid/sain/00013312_004.png
#   inflating: /content/DATA/valid/sain/00015826_020.png
#   inflating: /content/DATA/valid/sain/00002425_007.png
#   inflating: /content/DATA/valid/sain/00008561_015.png
#   inflating: /content/DATA/valid/sain/00023075_036.png
#   inflating: /content/DATA/valid/sain/00017158_020.png
#   inflating: /content/DATA/valid/sain/00014065_000.png
#   inflating: /content/DATA/valid/sain/00021019_000.png
#   inflating: /content/DATA/valid/sain/00020634_000.png
#   inflating: /content/DATA/valid/sain/00015826_023.png
#   inflating: /content/DATA/valid/sain/00029149_000.png
#   inflating: /content/DATA/valid/sain/00017158_011.png
#   inflating: /content/DATA/valid/sain/00020018_000.png
#   inflating: /content/DATA/valid/sain/00006249_003.png
#   inflating: /content/DATA/valid/sain/00006070_002.png
#   inflating: /content/DATA/valid/sain/00013312_000.png
#   inflating: /content/DATA/valid/sain/00009436_002.png
#   inflating: /content/DATA/valid/sain/00025381_005.png
#   inflating: /content/DATA/valid/sain/00025381_010.png
#   inflating: /content/DATA/valid/sain/00002855_000.png
#   inflating: /content/DATA/valid/sain/00010120_025.png
#   inflating: /content/DATA/valid/sain/00014856_000.png
#   inflating: /content/DATA/valid/sain/00004653_000.png
#   inflating: /content/DATA/valid/sain/00015058_000.png
#   inflating: /content/DATA/valid/sain/00017158_035.png
#   inflating: /content/DATA/valid/sain/00004640_000.png
#   inflating: /content/DATA/valid/sain/00026988_000.png
#   inflating: /content/DATA/valid/sain/00025381_003.png
#   inflating: /content/DATA/valid/sain/00001840_000.png
#   inflating: /content/DATA/valid/sain/00008345_000.png
#   inflating: /content/DATA/valid/sain/00001238_003.png
#   inflating: /content/DATA/valid/sain/00003998_000.png
#   inflating: /content/DATA/valid/sain/00001068_002.png
#   inflating: /content/DATA/valid/sain/00017158_000.png
#   inflating: /content/DATA/valid/sain/00014337_001.png
#   inflating: /content/DATA/valid/sain/00013143_000.png
#   inflating: /content/DATA/valid/sain/00022888_007.png
#   inflating: /content/DATA/valid/sain/00027947_000.png
#   inflating: /content/DATA/valid/sain/00023498_003.png
#   inflating: /content/DATA/valid/sain/00002387_005.png
#   inflating: /content/DATA/valid/sain/00017439_000.png
#   inflating: /content/DATA/valid/sain/00014844_001.png
#   inflating: /content/DATA/valid/sain/00001068_005.png
#   inflating: /content/DATA/valid/sain/00023498_000.png
#   inflating: /content/DATA/valid/sain/00007321_010.png
#   inflating: /content/DATA/valid/sain/00024208_000.png
#   inflating: /content/DATA/valid/sain/00006775_000.png
#   inflating: /content/DATA/valid/sain/00022796_000.png
#   inflating: /content/DATA/valid/sain/00009100_004.png
#   inflating: /content/DATA/valid/sain/00027531_000.png
#   inflating: /content/DATA/valid/sain/00030103_000.png
#   inflating: /content/DATA/valid/sain/00010223_000.png
#   inflating: /content/DATA/valid/sain/00003062_016.png
#   inflating: /content/DATA/valid/sain/00009727_030.png
#   inflating: /content/DATA/valid/sain/00019592_005.png
#   inflating: /content/DATA/valid/sain/00002425_008.png
#   inflating: /content/DATA/valid/sain/00003364_000.png
#   inflating: /content/DATA/valid/sain/00001248_013.png
#   inflating: /content/DATA/valid/sain/00015826_006.png
#   inflating: /content/DATA/valid/sain/00017158_052.png
#   inflating: /content/DATA/valid/sain/00023075_046.png
#   inflating: /content/DATA/valid/sain/00003364_001.png
#   inflating: /content/DATA/valid/sain/00002387_003.png
#   inflating: /content/DATA/valid/sain/00023922_000.png
#   inflating: /content/DATA/valid/sain/00026392_003.png
#   inflating: /content/DATA/valid/sain/00015058_001.png
#   inflating: /content/DATA/valid/sain/00002387_004.png
#   inflating: /content/DATA/valid/sain/00008345_002.png
#   inflating: /content/DATA/valid/sain/00009727_000.png
#   inflating: /content/DATA/valid/sain/00021609_008.png
#   inflating: /content/DATA/valid/sain/00005615_000.png
#   inflating: /content/DATA/valid/sain/00000888_000.png
#   inflating: /content/DATA/valid/sain/00025307_000.png
#   inflating: /content/DATA/valid/sain/00011237_055.png
#   inflating: /content/DATA/valid/sain/00029880_004.png
#   inflating: /content/DATA/valid/sain/00018548_001.png
#   inflating: /content/DATA/valid/sain/00011237_083.png
#   inflating: /content/DATA/valid/sain/00002793_006.png
#   inflating: /content/DATA/valid/sain/00008705_000.png
#   inflating: /content/DATA/valid/sain/00018548_000.png
#   inflating: /content/DATA/valid/sain/00023075_001.png
#   inflating: /content/DATA/valid/sain/00009727_033.png
#   inflating: /content/DATA/valid/sain/00012195_001.png
#   inflating: /content/DATA/valid/sain/00029202_000.png
#   inflating: /content/DATA/valid/sain/00008039_007.png
#   inflating: /content/DATA/valid/sain/00003062_000.png
#   inflating: /content/DATA/valid/sain/00013348_000.png
#   inflating: /content/DATA/valid/sain/00017671_000.png
#   inflating: /content/DATA/valid/sain/00006276_000.png
#   inflating: /content/DATA/valid/sain/00011237_000.png
#   inflating: /content/DATA/valid/sain/00006276_001.png
#   inflating: /content/DATA/valid/sain/00026524_015.png
#   inflating: /content/DATA/valid/sain/00004404_000.png
#   inflating: /content/DATA/valid/sain/00002022_003.png
#   inflating: /content/DATA/valid/sain/00024961_000.png
#   inflating: /content/DATA/valid/sain/00022060_001.png
#   inflating: /content/DATA/valid/sain/00023075_026.png
#   inflating: /content/DATA/valid/sain/00009001_004.png
#   inflating: /content/DATA/valid/sain/00024445_000.png
#   inflating: /content/DATA/valid/sain/00013026_001.png
#   inflating: /content/DATA/valid/sain/00010120_006.png
#   inflating: /content/DATA/valid/sain/00011237_056.png
#   inflating: /content/DATA/valid/sain/00017769_000.png
#   inflating: /content/DATA/valid/sain/00006533_001.png
#   inflating: /content/DATA/valid/sain/00020577_000.png
#   inflating: /content/DATA/valid/sain/00013312_009.png
#   inflating: /content/DATA/valid/sain/00015826_008.png
#   inflating: /content/DATA/valid/sain/00007994_000.png
#   inflating: /content/DATA/valid/sain/00026259_000.png
#   inflating: /content/DATA/valid/sain/00023498_010.png
#   inflating: /content/DATA/valid/sain/00023075_008.png
#   inflating: /content/DATA/valid/sain/00015357_000.png
#   inflating: /content/DATA/valid/sain/00011237_015.png
#   inflating: /content/DATA/valid/sain/00028549_000.png
#   inflating: /content/DATA/valid/sain/00009727_006.png
#   inflating: /content/DATA/valid/sain/00025008_000.png
#   inflating: /content/DATA/valid/sain/00007165_000.png
#   inflating: /content/DATA/valid/sain/00025381_006.png
#   inflating: /content/DATA/valid/sain/00022888_008.png
#   inflating: /content/DATA/valid/sain/00021274_011.png
#   inflating: /content/DATA/valid/sain/00013564_003.png
#   inflating: /content/DATA/valid/sain/00001750_000.png
#   inflating: /content/DATA/valid/sain/00019680_000.png
#   inflating: /content/DATA/valid/sain/00011237_044.png
#   inflating: /content/DATA/valid/sain/00023075_035.png
#   inflating: /content/DATA/valid/sain/00026389_001.png
#   inflating: /content/DATA/valid/sain/00028433_010.png
#   inflating: /content/DATA/valid/sain/00023075_032.png
#   inflating: /content/DATA/valid/sain/00002425_004.png
#   inflating: /content/DATA/valid/sain/00023498_005.png
#   inflating: /content/DATA/valid/sain/00017158_028.png
#   inflating: /content/DATA/valid/sain/00003212_003.png
#   inflating: /content/DATA/valid/sain/00026524_000.png
#   inflating: /content/DATA/valid/sain/00026524_010.png
#   inflating: /content/DATA/valid/sain/00002387_002.png
#   inflating: /content/DATA/valid/sain/00018794_000.png
#   inflating: /content/DATA/valid/sain/00012201_000.png
#   inflating: /content/DATA/valid/sain/00011237_002.png
#   inflating: /content/DATA/valid/sain/00001842_000.png
#   inflating: /content/DATA/valid/sain/00001248_035.png
#   inflating: /content/DATA/valid/sain/00015826_033.png
#   inflating: /content/DATA/valid/sain/00015826_010.png
#   inflating: /content/DATA/valid/sain/00026392_000.png
#   inflating: /content/DATA/valid/sain/00017158_022.png
#   inflating: /content/DATA/valid/sain/00017158_038.png
#   inflating: /content/DATA/valid/sain/00028549_011.png
#   inflating: /content/DATA/valid/sain/00027157_000.png
#   inflating: /content/DATA/valid/sain/00025968_000.png
#   inflating: /content/DATA/valid/sain/00002022_000.png
#   inflating: /content/DATA/valid/sain/00004264_001.png
#   inflating: /content/DATA/valid/sain/00019680_004.png
#   inflating: /content/DATA/valid/sain/00007292_000.png
#   inflating: /content/DATA/valid/sain/00015826_013.png
#   inflating: /content/DATA/valid/sain/00001248_034.png
#   inflating: /content/DATA/valid/sain/00028433_011.png
#   inflating: /content/DATA/valid/sain/00015826_014.png
#   inflating: /content/DATA/valid/sain/00021274_006.png
#   inflating: /content/DATA/valid/sain/00030161_000.png
#   inflating: /content/DATA/valid/sain/00011213_000.png
#   inflating: /content/DATA/valid/sain/00026428_000.png
#   inflating: /content/DATA/valid/sain/00007072_001.png
#   inflating: /content/DATA/valid/sain/00009727_002.png
#   inflating: /content/DATA/valid/sain/00015826_024.png
#   inflating: /content/DATA/valid/sain/00028433_014.png
#   inflating: /content/DATA/valid/sain/00027569_000.png
#   inflating: /content/DATA/valid/sain/00030710_000.png
#   inflating: /content/DATA/valid/sain/00021609_002.png
#   inflating: /content/DATA/valid/sain/00001568_000.png
#   inflating: /content/DATA/valid/sain/00028856_005.png
#   inflating: /content/DATA/valid/sain/00017158_010.png
#   inflating: /content/DATA/valid/sain/00011237_011.png
#   inflating: /content/DATA/valid/sain/00028549_007.png
#   inflating: /content/DATA/valid/sain/00022087_001.png
#   inflating: /content/DATA/valid/sain/00017158_042.png
#   inflating: /content/DATA/valid/sain/00007057_000.png
#   inflating: /content/DATA/valid/sain/00002298_000.png
#   inflating: /content/DATA/valid/sain/00018496_008.png
#   inflating: /content/DATA/valid/sain/00007072_002.png
#   inflating: /content/DATA/valid/sain/00004404_004.png
#   inflating: /content/DATA/valid/sain/00010268_000.png
#   inflating: /content/DATA/valid/sain/00010223_002.png
#   inflating: /content/DATA/valid/sain/00011237_075.png
#   inflating: /content/DATA/valid/sain/00008561_009.png
#   inflating: /content/DATA/valid/sain/00011237_045.png
#   inflating: /content/DATA/valid/sain/00001764_000.png
#   inflating: /content/DATA/valid/sain/00029880_002.png
#   inflating: /content/DATA/valid/sain/00009100_002.png
#   inflating: /content/DATA/valid/sain/00013564_000.png
#   inflating: /content/DATA/valid/sain/00010193_000.png
#   inflating: /content/DATA/valid/sain/00026439_002.png
#   inflating: /content/DATA/valid/sain/00002387_001.png
#   inflating: /content/DATA/valid/sain/00026988_001.png
#   inflating: /content/DATA/valid/sain/00010120_003.png
#   inflating: /content/DATA/valid/sain/00015447_001.png
#   inflating: /content/DATA/valid/sain/00015058_011.png
#   inflating: /content/DATA/valid/sain/00018276_000.png
#   inflating: /content/DATA/valid/sain/00006249_001.png
#   inflating: /content/DATA/valid/sain/00009727_007.png
#   inflating: /content/DATA/valid/sain/00023075_041.png
#   inflating: /content/DATA/valid/sain/00019992_000.png
#   inflating: /content/DATA/valid/sain/00011255_001.png
#   inflating: /content/DATA/valid/sain/00008561_002.png
#   inflating: /content/DATA/valid/sain/00007120_015.png
#   inflating: /content/DATA/valid/sain/00007221_000.png
#   inflating: /content/DATA/valid/sain/00013312_006.png
#   inflating: /content/DATA/valid/sain/00018567_000.png
#   inflating: /content/DATA/valid/sain/00009009_000.png
#   inflating: /content/DATA/valid/sain/00009727_038.png
#   inflating: /content/DATA/valid/sain/00012238_013.png
#   inflating: /content/DATA/valid/sain/00017158_005.png
#   inflating: /content/DATA/valid/sain/00011237_090.png
#   inflating: /content/DATA/valid/sain/00002425_002.png
#   inflating: /content/DATA/valid/sain/00001068_001.png
#   inflating: /content/DATA/valid/sain/00009727_017.png
#   inflating: /content/DATA/valid/sain/00023875_000.png
#   inflating: /content/DATA/valid/sain/00009727_029.png
#   inflating: /content/DATA/valid/sain/00020018_006.png
#   inflating: /content/DATA/valid/sain/00008561_005.png
#   inflating: /content/DATA/valid/sain/00000541_004.png
#   inflating: /content/DATA/valid/sain/00009727_022.png
#   inflating: /content/DATA/valid/sain/00026685_000.png
#   inflating: /content/DATA/valid/sain/00023075_042.png
#   inflating: /content/DATA/valid/sain/00023075_014.png
#   inflating: /content/DATA/valid/sain/00009436_008.png
#   inflating: /content/DATA/valid/sain/00011237_073.png
#   inflating: /content/DATA/valid/sain/00030055_000.png
#   inflating: /content/DATA/valid/sain/00011237_026.png
#   inflating: /content/DATA/valid/sain/00026428_003.png
#   inflating: /content/DATA/valid/sain/00008497_000.png
#   inflating: /content/DATA/valid/sain/00022764_010.png
#   inflating: /content/DATA/valid/sain/00012126_000.png
#   inflating: /content/DATA/valid/sain/00010223_001.png
#   inflating: /content/DATA/valid/sain/00000174_000.png
#   inflating: /content/DATA/valid/sain/00015447_000.png
#   inflating: /content/DATA/valid/sain/00024213_000.png
#   inflating: /content/DATA/valid/sain/00011237_092.png
#   inflating: /content/DATA/valid/sain/00011237_019.png
#   inflating: /content/DATA/valid/sain/00023498_006.png
#   inflating: /content/DATA/valid/sain/00010592_001.png
#   inflating: /content/DATA/valid/sain/00019508_002.png
#   inflating: /content/DATA/valid/sain/00016784_000.png
#   inflating: /content/DATA/valid/sain/00001248_009.png
#   inflating: /content/DATA/valid/sain/00022269_003.png
#   inflating: /content/DATA/valid/sain/00026570_001.png
#   inflating: /content/DATA/valid/sain/00016784_001.png
#   inflating: /content/DATA/valid/sain/00021019_001.png
#   inflating: /content/DATA/valid/sain/00029911_000.png
#   inflating: /content/DATA/valid/sain/00001347_001.png
#   inflating: /content/DATA/valid/sain/00011237_022.png
#   inflating: /content/DATA/valid/sain/00017158_036.png
#   inflating: /content/DATA/valid/sain/00015995_003.png
#   inflating: /content/DATA/valid/sain/00013123_003.png
#   inflating: /content/DATA/valid/sain/00020052_000.png
#   inflating: /content/DATA/valid/sain/00006070_005.png
#   inflating: /content/DATA/valid/sain/00017158_018.png
#   inflating: /content/DATA/valid/sain/00018794_002.png
#   inflating: /content/DATA/valid/sain/00008561_001.png
#   inflating: /content/DATA/valid/sain/00015731_000.png
#   inflating: /content/DATA/valid/sain/00027180_000.png
#   inflating: /content/DATA/valid/sain/00023075_044.png
#   inflating: /content/DATA/valid/sain/00008345_003.png
#   inflating: /content/DATA/valid/sain/00017336_000.png
#   inflating: /content/DATA/valid/sain/00010722_002.png
#   inflating: /content/DATA/valid/sain/00026439_000.png
#   inflating: /content/DATA/valid/sain/00002793_001.png
#   inflating: /content/DATA/valid/sain/00010722_000.png
#   inflating: /content/DATA/valid/sain/00004477_000.png
#   inflating: /content/DATA/valid/sain/00028433_008.png
#   inflating: /content/DATA/valid/sain/00026104_000.png
#   inflating: /content/DATA/valid/sain/00020483_000.png
#   inflating: /content/DATA/valid/sain/00024972_000.png
#   inflating: /content/DATA/valid/sain/00011237_111.png
#   inflating: /content/DATA/valid/sain/00008561_011.png
#   inflating: /content/DATA/valid/sain/00017158_032.png
#   inflating: /content/DATA/valid/sain/00021886_003.png
#   inflating: /content/DATA/valid/sain/00019992_002.png
#   inflating: /content/DATA/valid/sain/00006829_004.png
#   inflating: /content/DATA/valid/sain/00028632_000.png
#   inflating: /content/DATA/valid/sain/00016532_000.png
#   inflating: /content/DATA/valid/sain/00009436_000.png
#   inflating: /content/DATA/valid/sain/00001238_001.png
#   inflating: /content/DATA/valid/sain/00003211_004.png
#   inflating: /content/DATA/valid/sain/00005278_000.png
#   inflating: /content/DATA/valid/sain/00009727_010.png
#   inflating: /content/DATA/valid/sain/00026389_000.png
#   inflating: /content/DATA/valid/sain/00024359_000.png
#   inflating: /content/DATA/valid/sain/00004749_001.png
#   inflating: /content/DATA/valid/sain/00013312_005.png
#   inflating: /content/DATA/valid/sain/00017158_045.png
#   inflating: /content/DATA/valid/sain/00023075_049.png
#   inflating: /content/DATA/valid/sain/00018460_000.png
#   inflating: /content/DATA/valid/sain/00012238_003.png
#   inflating: /content/DATA/valid/sain/00023075_039.png
#   inflating: /content/DATA/valid/sain/00004264_000.png
#   inflating: /content/DATA/valid/sain/00011237_091.png
#   inflating: /content/DATA/valid/sain/00006070_006.png
#   inflating: /content/DATA/valid/sain/00015826_017.png
#   inflating: /content/DATA/valid/sain/00025381_002.png
#   inflating: /content/DATA/valid/sain/00012253_000.png
#   inflating: /content/DATA/valid/sain/00017158_029.png
#   inflating: /content/DATA/valid/sain/00012238_010.png
#   inflating: /content/DATA/valid/sain/00023498_009.png
#   inflating: /content/DATA/valid/sain/00015995_000.png
#   inflating: /content/DATA/valid/sain/00006249_006.png
#   inflating: /content/DATA/valid/sain/00015058_002.png
#   inflating: /content/DATA/valid/sain/00002387_007.png
#   inflating: /content/DATA/valid/sain/00013312_003.png
#   inflating: /content/DATA/valid/sain/00015058_008.png
#   inflating: /content/DATA/valid/sain/00011237_021.png
#   inflating: /content/DATA/valid/sain/00025305_001.png
#   inflating: /content/DATA/valid/sain/00007120_003.png
#   inflating: /content/DATA/valid/sain/00012641_002.png
#   inflating: /content/DATA/valid/sain/00000941_000.png
#   inflating: /content/DATA/valid/sain/00013348_001.png
#   inflating: /content/DATA/valid/sain/00008780_000.png
#   inflating: /content/DATA/valid/sain/00020052_001.png
#   inflating: /content/DATA/valid/sain/00023498_004.png
#   inflating: /content/DATA/valid/sain/00019431_000.png
#   inflating: /content/DATA/train/malade/00019927_006.png
#   inflating: /content/DATA/train/malade/00018629_001.png
#   inflating: /content/DATA/train/malade/00025626_000.png
#   inflating: /content/DATA/train/malade/00007632_013.png
#   inflating: /content/DATA/train/malade/00013670_032.png
#   inflating: /content/DATA/train/malade/00019177_000.png
#   inflating: /content/DATA/train/malade/00014663_047.png
#   inflating: /content/DATA/train/malade/00023170_007.png
#   inflating: /content/DATA/train/malade/00029300_001.png
#   inflating: /content/DATA/train/malade/00029807_007.png
#   inflating: /content/DATA/train/malade/00029807_000.png
#   inflating: /content/DATA/train/malade/00014663_018.png
#   inflating: /content/DATA/train/malade/00000248_017.png
#   inflating: /content/DATA/train/malade/00020857_002.png
#   inflating: /content/DATA/train/malade/00014285_013.png
#   inflating: /content/DATA/train/malade/00013658_001.png
#   inflating: /content/DATA/train/malade/00022103_000.png
#   inflating: /content/DATA/train/malade/00005426_000.png
#   inflating: /content/DATA/train/malade/00017864_000.png
#   inflating: /content/DATA/train/malade/00002766_002.png
#   inflating: /content/DATA/train/malade/00011683_044.png
#   inflating: /content/DATA/train/malade/00009728_000.png
#   inflating: /content/DATA/train/malade/00026810_026.png
#   inflating: /content/DATA/train/malade/00018921_026.png
#   inflating: /content/DATA/train/malade/00007063_000.png
#   inflating: /content/DATA/train/malade/00022554_000.png
#   inflating: /content/DATA/train/malade/00007296_003.png
#   inflating: /content/DATA/train/malade/00016668_006.png
#   inflating: /content/DATA/train/malade/00018921_009.png
#   inflating: /content/DATA/train/malade/00002243_006.png
#   inflating: /content/DATA/train/malade/00011683_017.png
#   inflating: /content/DATA/train/malade/00030636_004.png
#   inflating: /content/DATA/train/malade/00009523_003.png
#   inflating: /content/DATA/train/malade/00013216_005.png
#   inflating: /content/DATA/train/malade/00019605_005.png
#   inflating: /content/DATA/train/malade/00030107_004.png
#   inflating: /content/DATA/train/malade/00020922_000.png
#   inflating: /content/DATA/train/malade/00006905_000.png
#   inflating: /content/DATA/train/malade/00002206_006.png
#   inflating: /content/DATA/train/malade/00017311_000.png
#   inflating: /content/DATA/train/malade/00006045_000.png
#   inflating: /content/DATA/train/malade/00028523_003.png
#   inflating: /content/DATA/train/malade/00027685_007.png
#   inflating: /content/DATA/train/malade/00000980_003.png
#   inflating: /content/DATA/train/malade/00007076_009.png
#   inflating: /content/DATA/train/malade/00029406_000.png
#   inflating: /content/DATA/train/malade/00009049_003.png
#   inflating: /content/DATA/train/malade/00008279_000.png
#   inflating: /content/DATA/train/malade/00013370_001.png
#   inflating: /content/DATA/train/malade/00029548_007.png
#   inflating: /content/DATA/train/malade/00014663_017.png
#   inflating: /content/DATA/train/malade/00017189_000.png
#   inflating: /content/DATA/train/malade/00016819_003.png
#   inflating: /content/DATA/train/malade/00021188_004.png
#   inflating: /content/DATA/train/malade/00005746_004.png
#   inflating: /content/DATA/train/malade/00001968_000.png
#   inflating: /content/DATA/train/malade/00017544_000.png
#   inflating: /content/DATA/train/malade/00013670_087.png
#   inflating: /content/DATA/train/malade/00027356_000.png
#   inflating: /content/DATA/train/malade/00002061_000.png
#   inflating: /content/DATA/train/malade/00021565_002.png
#   inflating: /content/DATA/train/malade/00007076_022.png
#   inflating: /content/DATA/train/malade/00002316_005.png
#   inflating: /content/DATA/train/malade/00002952_004.png
#   inflating: /content/DATA/train/malade/00021058_000.png
#   inflating: /content/DATA/train/malade/00020024_002.png
#   inflating: /content/DATA/train/malade/00022415_006.png
#   inflating: /content/DATA/train/malade/00017405_022.png
#   inflating: /content/DATA/train/malade/00022458_005.png
#   inflating: /content/DATA/train/malade/00002206_000.png
#   inflating: /content/DATA/train/malade/00014140_010.png
#   inflating: /content/DATA/train/malade/00025196_000.png
#   inflating: /content/DATA/train/malade/00026810_004.png
#   inflating: /content/DATA/train/malade/00027202_004.png
#   inflating: /content/DATA/train/malade/00010371_000.png
#   inflating: /content/DATA/train/malade/00021663_003.png
#   inflating: /content/DATA/train/malade/00005114_000.png
#   inflating: /content/DATA/train/malade/00004381_048.png
#   inflating: /content/DATA/train/malade/00025600_003.png
#   inflating: /content/DATA/train/malade/00004381_026.png
#   inflating: /content/DATA/train/malade/00007676_012.png
#   inflating: /content/DATA/train/malade/00016743_000.png
#   inflating: /content/DATA/train/malade/00021626_003.png
#   inflating: /content/DATA/train/malade/00005746_009.png
#   inflating: /content/DATA/train/malade/00000231_000.png
#   inflating: /content/DATA/train/malade/00010943_003.png
#   inflating: /content/DATA/train/malade/00022065_022.png
#   inflating: /content/DATA/train/malade/00014888_012.png
#   inflating: /content/DATA/train/malade/00021499_013.png
#   inflating: /content/DATA/train/malade/00000248_015.png
#   inflating: /content/DATA/train/malade/00007676_016.png
#   inflating: /content/DATA/train/malade/00016668_004.png
#   inflating: /content/DATA/train/malade/00014888_021.png
#   inflating: /content/DATA/train/malade/00018921_058.png
#   inflating: /content/DATA/train/malade/00008543_002.png
#   inflating: /content/DATA/train/malade/00013670_020.png
#   inflating: /content/DATA/train/malade/00025400_001.png
#   inflating: /content/DATA/train/malade/00013648_026.png
#   inflating: /content/DATA/train/malade/00029201_000.png
#   inflating: /content/DATA/train/malade/00019265_007.png
#   inflating: /content/DATA/train/malade/00011683_000.png
#   inflating: /content/DATA/train/malade/00021626_011.png
#   inflating: /content/DATA/train/malade/00004381_024.png
#   inflating: /content/DATA/train/malade/00027411_001.png
#   inflating: /content/DATA/train/malade/00014285_011.png
#   inflating: /content/DATA/train/malade/00015171_003.png
#   inflating: /content/DATA/train/malade/00026810_047.png
#   inflating: /content/DATA/train/malade/00021499_021.png
#   inflating: /content/DATA/train/malade/00013670_144.png
#   inflating: /content/DATA/train/malade/00030636_000.png
#   inflating: /content/DATA/train/malade/00028187_001.png
#   inflating: /content/DATA/train/malade/00007076_010.png
#   inflating: /content/DATA/train/malade/00018150_001.png
#   inflating: /content/DATA/train/malade/00009523_004.png
#   inflating: /content/DATA/train/malade/00021860_003.png
#   inflating: /content/DATA/train/malade/00013670_054.png
#   inflating: /content/DATA/train/malade/00015264_006.png
#   inflating: /content/DATA/train/malade/00009378_011.png
#   inflating: /content/DATA/train/malade/00021663_001.png
#   inflating: /content/DATA/train/malade/00011683_039.png
#   inflating: /content/DATA/train/malade/00001549_021.png
#   inflating: /content/DATA/train/malade/00025841_005.png
# ...
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch) (1.4.3)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (26.0)
# Requirement already satisfied: lightning-utilities>=0.15.3 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (0.15.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (1.78.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (3.10.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (5.29.6)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (3.1.6)
# Requirement already satisfied: PyYAML<8.0,>5.4 in /usr/local/lib/python3.12/dist-packages (from lightning) (6.0.3)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from lightning) (4.67.3)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.12/dist-packages (from lightning) (2.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit_learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit_learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit_learn) (3.6.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel) (6.5.1)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel) (5.7.1)
# Requirement already satisfied: narwhals>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from fairlearn) (2.18.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (9.1.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from nbformat) (5.9.1)
# Requirement already satisfied: skorch in /usr/local/lib/python3.12/dist-packages (from aif360[inFairness]) (1.3.1)
# Requirement already satisfied: inFairness>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from aif360[inFairness]) (0.2.3)
# Requirement already satisfied: tensorflow>=1.13.1 in /usr/local/lib/python3.12/dist-packages (from aif360[AdversarialDebiasing]) (2.19.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from causal-learn) (0.21)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (from causal-learn) (0.14.6)
# Requirement already satisfied: pydot in /usr/local/lib/python3.12/dist-packages (from causal-learn) (4.0.1)
# Requirement already satisfied: momentchi2 in /usr/local/lib/python3.12/dist-packages (from causal-learn) (0.1.8)
# Requirement already satisfied: osqp>=0.6.2 in /usr/local/lib/python3.12/dist-packages (from cvxpy) (1.1.1)
# Requirement already satisfied: clarabel>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from cvxpy) (0.11.1)
# Requirement already satisfied: scs>=3.2.4.post1 in /usr/local/lib/python3.12/dist-packages (from cvxpy) (3.2.11)
# Requirement already satisfied: raiutils>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dice-ml) (0.4.2)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (from dice-ml) (3.2.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (from dice-ml) (4.6.0)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.12/dist-packages (from lime) (0.25.2)
# Requirement already satisfied: cffi in /usr/local/lib/python3.12/dist-packages (from clarabel>=0.5.0->cvxpy) (2.0.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning) (3.13.3)
# Requirement already satisfied: POT>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from inFairness>=0.2.2->aif360[inFairness]) (0.9.6.post1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat) (0.30.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.9.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from raiutils>=0.4.0->dice-ml) (2.32.4)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.12->lime) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.12->lime) (2026.3.3)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.12->lime) (0.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (3.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (2.1.2)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (3.13.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (3.16.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (0.5.4)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard) (3.0.3)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.12/dist-packages (from skorch->aif360[inFairness]) (0.9.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels->causal-learn) (1.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (1.23.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (0.46.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.6)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (0.19.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel) (0.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->raiutils>=0.4.0->dice-ml) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->raiutils>=0.4.0->dice-ml) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->raiutils>=0.4.0->dice-ml) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->raiutils>=0.4.0->dice-ml) (2026.2.25)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi->clarabel>=0.5.0->cvxpy) (3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (0.1.2)

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from aif360.sklearn.metrics import *

import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets as widgets
from IPython.display import display

from scipy.stats import chi2_contingency


#from train_classifieur import train_classifier, pred_classifier

# %%
# On commence par charger les donnees depuis le csv
df = pd.read_csv(DATADIR/'metadata.csv')      #j'ai chargé mes données, il faudra decider lequels utiliser

# On peut regarder les premieres lignes du dataset
df.head()
# Out:
#         Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 0  00000011_000.png       Effusion            0          11           75
# 1  00000011_001.png     No Finding            1          11           75
# 2  00000011_002.png     No Finding            2          11           75
# 3  00000011_003.png     No Finding            3          11           75
# 4  00000011_004.png     No Finding            4          11           75
#
#   Patient Gender View Position  OriginalImage[Width  Height]  \
# 0              M            PA                 2638     2449
# 1              M            PA                 2500     2048
# 2              M            PA                 2714     2781
# 3              M            PA                 2500     2048
# 4              M            PA                 2500     2048
#
#    OriginalImagePixelSpacing[x     y]  Unnamed: 11 train_valid   label  \
# 0                        0.143  0.143          NaN       train  malade
# 1                        0.168  0.168          NaN       train    sain
# 2                        0.143  0.143          NaN       train    sain
# 3                        0.168  0.168          NaN       train    sain
# 4                        0.168  0.168          NaN       train    sain
#
#    WEIGHTS
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %% [markdown]
# # 1 - Préparation des données :

# %% [markdown]
# Dans cette partie, une analyse est réalisée afin d’observer les dimensions du dataset, les types de variables ainsi que leur distribution. Une attention particulière est portée à la détection de valeurs abhérrantes, notamment sur la variable âge, afin de garantir la cohérence des informations.
#
# Enfin, certaines transformations sont effectuées pour faciliter l’analyse, notamment la création d’une variable binaire indiquant la présence ou l’absence de maladie, ainsi que la catégorisation de l’âge en groupes. Ces étapes permettent d’obtenir un dataset propre, structuré et adapté à l’analyse des biais

# %% [markdown]
# # Informations sur le Dataset

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5593 entries, 0 to 5592
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Image Index                  5593 non-null   object
#  1   Finding Labels               5593 non-null   object
#  2   Follow-up #                  5593 non-null   int64
#  3   Patient ID                   5593 non-null   int64
#  4   Patient Age                  5593 non-null   int64
#  5   Patient Gender               5593 non-null   object
#  6   View Position                5593 non-null   object
#  7   OriginalImage[Width          5593 non-null   int64
#  8   Height]                      5593 non-null   int64
#  9   OriginalImagePixelSpacing[x  5593 non-null   float64
#  10  y]                           5593 non-null   float64
#  11  Unnamed: 11                  0 non-null      float64
#  12  train_valid                  5593 non-null   object
#  13  label                        5593 non-null   object
#  14  WEIGHTS                      5593 non-null   int64
# dtypes: float64(3), int64(6), object(6)
# memory usage: 655.6+ KB

# %% [markdown]
# On observe que le dataset contient 5593 observations de patients et 14 variables.
# Ces variables sont composées d'informations démographiques (age, genre), d'informations techniques (position de vue, taille de l'image originelle, le spacing des pixels) ainsi que le nombre de visites effectués préalablement et si le patient il est malade ou sain (Finding Labels contient les maladies identifiés si il en a). Cette dernière infomartion sera notre label car l'objectif est de prédire si le patient est malade ou pas. Additionelement, on a comme information si l'image a été utilisée dans le train set ou le validation set et le poids avec lequel elle va être utilisée dans l'entrainement de notre modèle.

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Tout d'abord on a vu avec df.info() qu'il n'y a pas de valeurs nulles dans notre dataset sauf pour la colonne 'Unnamed: 11' qui est une erreur et tous les types des données sont bien placés. Pas besoin de traiter nos données pour ceci.

# %% [markdown]
# On remarque que les informations OriginalImage[Width, Height] et OriginalImagePixelSpacing[x y] données par les colonnes 'OriginalImage[Width', 'Height]', 'OriginalImagePixelSpacing[x', 'y]' n'apportent aucune information intéressante. De même pour la colonne Unnamed: 11 qui c'est probablement glissée dans les métadonnées par erreur. On peut donc procéder à le supprimer.

# %%
df = df.drop(columns=['OriginalImage[Width', 'Height]', 'OriginalImagePixelSpacing[x', 'y]', 'Unnamed: 11'])

# %%
df
# Out:
#            Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 0     00000011_000.png       Effusion            0          11           75
# 1     00000011_001.png     No Finding            1          11           75
# 2     00000011_002.png     No Finding            2          11           75
# 3     00000011_003.png     No Finding            3          11           75
# 4     00000011_004.png     No Finding            4          11           75
# ...                ...            ...          ...         ...          ...
# 5588  00030772_001.png  Consolidation            1       30772           26
# 5589  00030772_002.png  Consolidation            2       30772           26
# 5590  00030774_000.png  Consolidation            0       30774           44
# 5591  00030784_000.png     No Finding            0       30784           25
# 5592  00030803_000.png     No Finding            0       30803           42
#
#      Patient Gender View Position train_valid   label  WEIGHTS
# 0                 M            PA       train  malade        1
# 1                 M            PA       train    sain        1
# 2                 M            PA       train    sain        1
# 3                 M            PA       train    sain        1
# 4                 M            PA       train    sain        1
# ...             ...           ...         ...     ...      ...
# 5588              F            AP       train  malade        1
# 5589              F            AP       train  malade        1
# 5590              F            PA       valid  malade        1
# 5591              F            PA       train    sain        1
# 5592              F            PA       valid    sain        1
#
# [5593 rows x 10 columns]

# %% [markdown]
# À partir de ce que l'on a trouvé lors du mi-projet on peut faire le nettoyage de nos données rapidement. On regarde qu'il n'y ai pas d'index répétés, que les valeurs numériques soient cohérentes, que les valeurs de type object fassent partie des valeurs possibles.

# %%
if not (df['Image Index'].is_unique):
    print("Les index ne sont pas individuels")
if ((df["Follow-up #"] < 0).any()):
    print("Il y a des Follow-up négatifs")
if ((df["Patient Age"] < 0).any()):
    print("Il y a des âges négatifs")
if ((df["Patient Age"] > 110).any()):
    print("Il y a des âges plus grands que 110")
if (set(df["Patient Gender"]) != {'F', 'M'}):
    print("Le patient gender prend des valeures différentes de \"M\" ou \"F\"")
if (set(df["View Position"]) != {'AP', 'PA'}):
    print("Le view position prend des valeures différentes de \"AP\" ou \"PA\"")
if (set(df["train_valid"]) != {'train', 'valid'}):
    print("La colonne train_valid prend des valeures différentes de \"train\" ou \"valid\"")
if (set(df["label"]) != {'malade', 'sain'}):
    print("La colonne label prend des valeures différentes de \"malade\" ou \"sain\"")
# Out:
# Il y a des âges plus grands que 110

# %% [markdown]
# Le seul nettoyage à faire et donc sur les âges. On observe des âges supérieurs à 110 et biologiquement improbables. Plutôt que de supprimer directement les lignes dans le dataframe, une vérification va été effectuée au niveau de chaque Patient ID afin d’examiner si d’autres enregistrements du même patient comportent un âge cohérent. Lorsque c’était le cas, on va corriger l’âge abhérrant en utilisant l’âge de référence du patient, défini comme l'âge le plus fréquent ou sinon la médiane des âges observés.

# %%
df = df[df["Patient Age"] <= 110]

# %% [markdown]
# ## Transformation des colonnes

# %% [markdown]
# Pour l'analyse descriptive des données on va procéder à faire un multi one-hot encoding sur la colonne finding labels en créant une colonne par maladie.
# De plus, afin de simplifier la lecture des données âge et pouvoir les utiliser dans le préprocessing on va la transformer en une donnée catégorielle en créant des tranches d'âges.

# %%
# on crée les tranches d'âge
df["Age_Group"] = pd.cut(
    df["Patient Age"],
    bins=[0, 20, 40, 60, 80, 120],
    labels=["0-20", "20-40", "40-60", "60-80", "80+"],
    right=False
)
# on ne supprime pas la colonne avec les âges exacts au cas ou on devrais en vaoir besoin après mais en principe il n'y a pas besoin
# Out:
# /tmp/ipykernel_10136/3754337491.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Age_Group"] = pd.cut(

# %%
# on crée les tranches de follow ups pour faciliter la visualisation
df["Follow-up_Group"] = pd.cut(
    df["Follow-up #"],
    bins=[0, 5, 10, 15, 25, 50, 500],
    labels=["0-5", "5-10", "10-15", "15-25", "25-50", "50+"],
    right=False
)
# on ne supprime pas la colonne avec les âges exacts au cas ou on devrais en vaoir besoin après mais en principe il n'y a pas besoin
# Out:
# /tmp/ipykernel_10136/2379387146.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Follow-up_Group"] = pd.cut(

# %%
# on fait le one_hot sur les phatologies
dummies = df["Finding Labels"].str.get_dummies(sep="|")

df_one_hot = pd.concat([df, dummies], axis=1)
df_one_hot = df_one_hot.drop(columns=["Finding Labels"])

# %%
df.head()
# Out:
#         Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 0  00000011_000.png       Effusion            0          11           75
# 1  00000011_001.png     No Finding            1          11           75
# 2  00000011_002.png     No Finding            2          11           75
# 3  00000011_003.png     No Finding            3          11           75
# 4  00000011_004.png     No Finding            4          11           75
#
#   Patient Gender View Position train_valid   label  WEIGHTS Age_Group  \
# 0              M            PA       train  malade        1     60-80
# 1              M            PA       train    sain        1     60-80
# 2              M            PA       train    sain        1     60-80
# 3              M            PA       train    sain        1     60-80
# 4              M            PA       train    sain        1     60-80
#
#   Follow-up_Group
# 0             0-5
# 1             0-5
# 2             0-5
# 3             0-5
# 4             0-5

# %% [markdown]
# Maintenant on a deux tableaux, l'un avec les maladies codées en one-hot pour l'analyse et un sans le one-hot pour l'entrainement du modèle

# %% [markdown]
# ## Analyse des données

# %% [markdown]
# Dans cette partie, on va réaliser une analyse univariée afin de comprendre la distribution individuelle des variables clés, telles que le genre, l’âge et le statut de maladie.
#
# Avec une analyse bivariée on va ensuite examiner la relation entre les attributs sensibles (genre et groupes d’âge) et le label, afin de détecter d’éventuelles disparités.
#
# Enfin, on va réaliser une analyse multivariée qui approfondi l’étude en combinant plusieurs variables, suivie du calcul de métriques d’équité telles que le Statistical Parity Difference et le Disparate Impact, ce qui permet de quantifier les biais potentiels présents dans les données.

# %% [markdown]
# ### A) Analyse univarié

# %% [markdown]
# On va regarder les données importantes une par une et les anlyser.

# %%
counts = [["label", "Patient Gender"], ["Follow-up_Group", "View Position"], ["Age_Group", "Patient Age"]]
titre = [["des labels", "du genre des patients"], ["des regroupements des follow-ups", "de la position de vue"], ["des groupes d'âge", "des âges"]]

fig, axes = plt.subplots(3, 2, figsize=(14,10))

for i in range(3):
    for j in range(2):
        if(i == 2 and j == 1):
            axes[i][j].hist(df[counts[i][j]], bins=30, edgecolor="black")
            axes[i][j].set_xlabel("Âge")
            axes[i][j].set_ylabel("Nombre d'images")
            axes[i][j].grid(axis="y", linestyle="--", alpha=0.6)
        else:
            axes[i][j].pie(
                df[counts[i][j]].value_counts(),
                labels = df[counts[i][j]].value_counts().index,
                autopct=lambda pct: f"{pct:.1f}%" if pct > 5 else "",
                startangle = 90,
                colors = ["steelblue", "lightcoral", "mediumseagreen", "gold", "mediumpurple", "red"] if ((i == 2 and j == 0) or (i == 1 and j == 0)) else ["steelblue", "lightcoral"],
                wedgeprops={"edgecolor": "black"},
            )

        axes[i][j].set_title(f"Distribution {titre[i][j]}", fontsize=13, pad=15)

fig.suptitle("Vue d'ensemble du dataset", fontsize=16, fontweight="bold")
plt.tight_layout()
plt.show()

# %% [markdown]
# L’analyse univariée a permis de caractériser la distribution de chaque variable (tendance centrale, dispersion, forme) et de détecter des déséquilibres entre certaines valeures.
#
# L'analyse univariée sur le genre montre une légère prédominance des hommes sur les femmes, representés respectivement par 57% et 43% des observations.
# Cela ne constitue pas un désequilibre majeur mais il faut le prendre en compte lors de l'analyse de biais.
#
#
# # !!INTERPRETER!!

# %% [markdown]
# ### B) Analyse bivariée

# %% [markdown]
# On va maintenant mettre en relation les données deux à deux et les analyser ainsi.

# %%
#Genre × Maladie
table_genre_maladie = pd.crosstab(
    df["Patient Gender"],
    df["label"],
    normalize="index"
) * 100

#Age_group × Maladie
table_age_maladie = pd.crosstab(
    df["Age_Group"],
    df["label"],
    normalize="index"
) * 100

#View Position × Maladie
table_View_maladie = pd.crosstab(
    df["View Position"],
    df["label"],
    normalize="index"
) * 100

#Follow ups × Maladie
table_Follow_maladie = pd.crosstab(
    df["Follow-up_Group"],
    df["label"],
    normalize="index"
) * 100

counts = [[table_genre_maladie, table_age_maladie], [table_View_maladie, table_Follow_maladie]]
titre = [["Genre × Présence de maladie", "Âge × Présence de maladie"], ["Position de Vue × Présence de maladie", "Follow Ups × Présence de maladie"]]

fig, axes = plt.subplots(2, 2, figsize=(14,10))

for i in range(2):
    for j in range(2):
        counts[i][j].plot(kind="bar", ax=axes[i][j])
        axes[i][j].set_ylabel("Pourcentage (%)")
        axes[i][j].tick_params(axis='x', rotation=0)
        axes[i][j].legend(["Sain", "Malade"])

        axes[i][j].set_title(titre[i][j])

fig.suptitle("Analyse bivariée du dataset", fontsize=16, fontweight="bold")
plt.tight_layout()
plt.show()



#age*genre
#genre*view position
#age*view position
#genre*follow up
#age*follow up

#analyse triple

# %%
## analyse détaillée des résultats

print(f"Différence hommes - femmes : {(table_genre_maladie.loc["M", "malade"] - table_genre_maladie.loc["F", "malade"]):.2f}%")
contingence = pd.crosstab(df["Patient Gender"], df["label"])
chi2, p, dof, expected = chi2_contingency(contingence)

print("p-value :", p)
rr = table_genre_maladie.loc["M", "malade"] / table_genre_maladie.loc["F", "malade"]
print(rr)


# On prend comme groupe de référence le groupe d'âge 40-60 car c'est le groupe avec le plus de valeures et le plus stable statistiquement
print("\n")
print("\n")
print(table_age_maladie["malade"] - table_age_maladie["malade"]["40-60"])

contingence = pd.crosstab(df["Age_Group"],df["label"])
chi2, p, dof, expected = chi2_contingency(contingence)
print("\n")
print("p-value :", p)
print("\n")
rr = table_age_maladie / table_age_maladie["malade"]["40-60"]
print(rr)
# Out:
# Différence hommes - femmes : -0.45%
# p-value : 0.7633824344663006
# 0.9906276458103747
#
#
#
#
# Age_Group
# 0-20     -7.576767
# 20-40    -6.101357
# 40-60     0.000000
# 60-80     6.269387
# 80+      20.715916
# Name: malade, dtype: float64
#
#
# p-value : 7.813846093633881e-11
#
#
# label        malade      sain
# Age_Group
# 0-20       0.840747  1.261120
# 20-40      0.871758  1.230109
# 40-60      1.000000  1.101866
# 60-80      1.131774  0.970092
# 80+        1.435421  0.666445

# %% [markdown]
# Le test du χ² donne une p-value de 0.0196, inférieure au seuil de 5 %, ce qui indique que la relation entre le genre et la présence de maladie est statistiquement significative. Toutefois, l’écart observé entre les proportions reste modéré, ce qui suggère que l’effet est présent mais de faible ampleur.Le risk ratio est égal à 1.06, ce qui signifie que les hommes ont une probabilité environ 6 % plus élevée de présenter une pathologie que les femmes. Bien que statistiquement significative, cette différence reste modérée.

# %% [markdown]
# analyse manquante

# %% [markdown]
# # PreProcessing

# %% [markdown]
# On a vu plusieurs methods de preprocessing, mais dans le cas le modele avec lequelle on travaille prends en entree seulement les images, et pas les metadonnees.
# C'es la raison que les methodes de DIR(Disperate Impact Remover) et LFR(Learn fair representations) ne sont pas appliquables , et le seul methode de Preprocessing qu'on peut appliquer est le Reweighting

# %% [markdown]
# On va comparer trois différentes versions :
#
# - *Baseline* : résultats sans application du reweighting.
# - *RW_Gender* : application du reweighting en utilisant le genre comme attribut sensible.
# - *RW_Age* : application du reweighting en utilisant l’âge comme attribut sensible.

# %% [markdown]
# D’abord, définissons les méthodes que nous allons utiliser pour analyser les performances et les métriques de fairness.

# %%
import numpy as np
import pandas as pd
from datetime import datetime
from pathlib import Path

from IPython.display import Markdown, display
from aif360.datasets import StandardDataset
from aif360.algorithms.preprocessing import Reweighing
from aif360.sklearn.metrics import *
from sklearn.metrics import balanced_accuracy_score, accuracy_score

from train_classifieur import train_classifier, pred_classifier


def get_metrics(
    y_true, # list or np.array of truth values
    y_pred=None,  # list or np.array of predictions
    prot_attr=None, # list or np.array of protected/sensitive attribute values
    priv_group=1, # value taken by the privileged group
    pos_label=1, # value taken by the positive truth/prediction
    sample_weight=None # list or np.array of weights value,
):
    group_metrics = {}
    group_metrics["base_rate_truth"] = base_rate(
        y_true=y_true, pos_label=pos_label, sample_weight=sample_weight
    )
    group_metrics["statistical_parity_difference"] = statistical_parity_difference(
        y_true=y_true, y_pred=y_pred, prot_attr=prot_attr, priv_group=priv_group, pos_label=pos_label, sample_weight=sample_weight
    )
    group_metrics["disparate_impact_ratio"] = disparate_impact_ratio(
        y_true=y_true, y_pred=y_pred, prot_attr=prot_attr, priv_group=priv_group, pos_label=pos_label, sample_weight=sample_weight
    )
    if not y_pred is None:
        group_metrics["base_rate_preds"] = base_rate(
        y_true=y_pred, pos_label=pos_label, sample_weight=sample_weight
        )
        group_metrics["equal_opportunity_difference"] = equal_opportunity_difference(
            y_true=y_true, y_pred=y_pred, prot_attr=prot_attr, priv_group=priv_group, pos_label=pos_label, sample_weight=sample_weight
        )
        group_metrics["average_odds_difference"] = average_odds_difference(
            y_true=y_true, y_pred=y_pred, prot_attr=prot_attr, priv_group=priv_group, pos_label=pos_label, sample_weight=sample_weight
        )
        if len(set(y_pred))>1:
            group_metrics["conditional_demographic_disparity"] = conditional_demographic_disparity(
                y_true=y_true, y_pred=y_pred, prot_attr=prot_attr, pos_label=pos_label, sample_weight=sample_weight
            )
        else:
            group_metrics["conditional_demographic_disparity"] =None
        group_metrics["smoothed_edf"] = smoothed_edf(
        y_true=y_true, y_pred=y_pred, prot_attr=prot_attr, pos_label=pos_label, sample_weight=sample_weight
        )
        group_metrics["df_bias_amplification"] = df_bias_amplification(
        y_true=y_true, y_pred=y_pred, prot_attr=prot_attr, pos_label=pos_label, sample_weight=sample_weight
        )
        group_metrics["balanced_accuracy_score"] = balanced_accuracy_score(
        y_true=y_true, y_pred=y_pred, sample_weight=sample_weight
        )
    return group_metrics

# %% [markdown]
# On repart de notre DataFrame nettoyé. On y ajoute des colonnes correspondant à des attributs binaires pour l’analyse de fairness

# %%
df_model = df.copy()

for weight_col in ["WEIGHTS"]:
    df_model[weight_col] = pd.to_numeric(df_model[weight_col], errors="coerce").fillna(1.0)

df_model["label_bin"] = (df_model["label"] == "malade").astype(int)
df_model["gender_bin"] = (df_model["Patient Gender"] == "M").astype(int)
df_model["age_bin"] = (df_model["Patient Age"] >= 60).astype(int)

df_model_train = df_model[df_model["train_valid"] == "train"].copy()
df_model_valid = df_model[df_model["train_valid"] == "valid"].copy()

print(f"Nombre d'images train : {len(df_model_train)}")
print(f"Nombre d'images valid : {len(df_model_valid)}")

df_model[["Image Index", "label", "WEIGHTS", "label_bin", "gender_bin", "age_bin"]].head()
# Out:
# Nombre d'images train : 4135
# Nombre d'images valid : 1457
#         Image Index   label  WEIGHTS  label_bin  gender_bin  age_bin
# 0  00000011_000.png  malade        1          1           1        1
# 1  00000011_001.png    sain        1          0           1        1
# 2  00000011_002.png    sain        1          0           1        1
# 3  00000011_003.png    sain        1          0           1        1
# 4  00000011_004.png    sain        1          0           1        1

# %% [markdown]
# On définit une méthode pour effectuer le reweighting.

# %%
def apply_reweighing(df_model, protected_col, output_weight_col):
    df_train = df_model[df_model["train_valid"] == "train"].copy()
    df_valid = df_model[df_model["train_valid"] == "valid"].copy()

    dataset_train = StandardDataset(
        df=df_train[["label_bin", protected_col, "WEIGHTS"]].copy(),
        label_name="label_bin",
        favorable_classes=[1],
        protected_attribute_names=[protected_col],
        privileged_classes=[[1]],
        instance_weights_name="WEIGHTS",
    )
    dataset_val = StandardDataset(
        df=df_valid[["label_bin", protected_col, "WEIGHTS"]].copy(),
        label_name="label_bin",
        favorable_classes=[1],
        protected_attribute_names=[protected_col],
        privileged_classes=[[1]],
        instance_weights_name="WEIGHTS",
    )

    sens_ind = 0
    sens_attr = dataset_train.protected_attribute_names[sens_ind]
    unprivileged_groups = [
        {sens_attr: v}
        for v in dataset_train.unprivileged_protected_attributes[sens_ind]
    ]
    privileged_groups = [
        {sens_attr: v}
        for v in dataset_train.privileged_protected_attributes[sens_ind]
    ]

    RW = Reweighing(
        unprivileged_groups=unprivileged_groups,
        privileged_groups=privileged_groups,
    )
    RW.fit(dataset_train)
    dataset_transf_train = RW.transform(dataset_train)
    dataset_transf_val = RW.transform(dataset_val)

    df_model.loc[df_train.index, output_weight_col] = dataset_transf_train.instance_weights
    df_model.loc[df_valid.index, output_weight_col] = dataset_transf_val.instance_weights

    return {
        "sens_attr": sens_attr,
        "unprivileged_groups": unprivileged_groups,
        "privileged_groups": privileged_groups,
        "dataset_train": dataset_transf_train,
        "dataset_val": dataset_transf_val,
    }

# %%
gender_reweighing = apply_reweighing(df_model, "gender_bin", "WEIGHTS_GENDER")
age_reweighing = apply_reweighing(df_model, "age_bin", "WEIGHTS_AGE")

reweighing_setup = pd.DataFrame(
    [
        {
            "Attribut": "genre",
            "Colonne poids": "WEIGHTS_GENDER",
            "Attribut sensible": gender_reweighing["sens_attr"],
            "Groupes non privilégiés": str(gender_reweighing["unprivileged_groups"]),
            "Groupes privilégiés": str(gender_reweighing["privileged_groups"]),
        },
        {
            "Attribut": "âge",
            "Colonne poids": "WEIGHTS_AGE",
            "Attribut sensible": age_reweighing["sens_attr"],
            "Groupes non privilégiés": str(age_reweighing["unprivileged_groups"]),
            "Groupes privilégiés": str(age_reweighing["privileged_groups"]),
        },
    ]
)
reweighing_setup
# Out:
#   Attribut   Colonne poids Attribut sensible  \
# 0    genre  WEIGHTS_GENDER        gender_bin
# 1      âge     WEIGHTS_AGE           age_bin
#
#              Groupes non privilégiés                Groupes privilégiés
# 0  [{'gender_bin': np.float64(0.0)}]  [{'gender_bin': np.float64(1.0)}]
# 1     [{'age_bin': np.float64(0.0)}]     [{'age_bin': np.float64(1.0)}]

# %% [markdown]
# On vérifie que le reweighting a bien fonctionné et que l’on obtient des poids différents pour les différents exemples.

# %%
weight_check = pd.DataFrame(
    {
        "WEIGHTS": df_model["WEIGHTS"].describe(),
        "WEIGHTS_GENDER": df_model["WEIGHTS_GENDER"].describe(),
        "WEIGHTS_AGE": df_model["WEIGHTS_AGE"].describe(),
    }
)

assert df_model["WEIGHTS"].nunique() == 1
assert df_model["WEIGHTS_GENDER"].nunique() > 1
assert df_model["WEIGHTS_AGE"].nunique() > 1


weight_check
# Out:
#        WEIGHTS  WEIGHTS_GENDER  WEIGHTS_AGE
# count   5592.0     5592.000000  5592.000000
# mean       1.0        1.000292     0.999399
# std        0.0        0.014819     0.068146
# min        1.0        0.982578     0.888950
# 25%        1.0        0.988173     0.962500
# 50%        1.0        1.010712     0.962500
# 75%        1.0        1.010712     1.046022
# max        1.0        1.020432     1.124385

# %% [markdown]
# On sauvegarde le jeu de données dans trois fichiers CSV pour entraîner le modèle.

# %%
run_root = Path("./expe_log")
run_root.mkdir(parents=True, exist_ok=True)

baseline_csv = run_root / "metadata_baseline.csv"
gender_csv = run_root / "metadata_gender.csv"
age_csv = run_root / "metadata_age.csv"

df_model.to_csv(baseline_csv, index=False)
df_model.to_csv(gender_csv, index=False)
df_model.to_csv(age_csv, index=False)


print("baseline", "CSV: ", str(baseline_csv))
print("Gender fair model", "CSV: ", str(gender_csv))
print("Age fair model", "CSV: ", str(age_csv))
# Out:
# baseline CSV:  expe_log/metadata_baseline.csv
# Gender fair model CSV:  expe_log/metadata_gender.csv
# Age fair model CSV:  expe_log/metadata_age.csv

# %% [markdown]
# On entraine le modele et fait des predictions

# %%
#-------------
#CREER UN DOSSIER 'FAIRNESS' SUR DRIVE AVEC LE FICHIER ZIP ET train_classifieur.py
#---------------------
def train_and_predict(name, csv_path, weights_col, preds_col, run_root):
    logdir = run_root / name
    logdir.mkdir(parents=True, exist_ok=True)

    ckpt_path, ckpt_score = train_classifier(
        logdir=str(logdir),
        datadir=DATADIR,
        csv=str(csv_path),
        weights_col=weights_col,
    )

    preds_csv = logdir / f"{preds_col}.csv"
    pred_classifier(
        datadir=DATADIR,
        csv_in=str(csv_path),
        csv_out=str(preds_csv),
        ckpt_path=ckpt_path,
        preds_col=preds_col,
    )

    return {
        "name": name,
        "csv_path": csv_path,
        "weights_col": weights_col,
        "preds_col": preds_col,
        "logdir": logdir,
        "ckpt_path": ckpt_path,
        "ckpt_score": ckpt_score,
        "preds_csv": preds_csv,
    }

# %%
# !mkdir -p ./expe_log
# !cp -r /content/drive/MyDrive/fairness/baseline ./expe_log/
# !cp -r /content/drive/MyDrive/fairness/gender ./expe_log/
# !cp -r /content/drive/MyDrive/fairness/age ./expe_log/

baseline_preds_csv = run_root / "baseline" / "preds_baseline.csv"
gender_preds_csv = run_root / "gender" / "preds_gender_rw.csv"
age_preds_csv = run_root / "age" / "preds_age_rw.csv"

if not baseline_preds_csv.exists():

    baseline_run = train_and_predict(
        name="baseline",
        csv_path=baseline_csv,
        weights_col="WEIGHTS",
        preds_col="preds_baseline",
        run_root=run_root,
    )
    baseline_preds_csv = baseline_run["preds_csv"]
if not gender_preds_csv.exists():

    gender_run = train_and_predict(
        name="gender",
        csv_path=gender_csv,
        weights_col="WEIGHTS_GENDER",
        preds_col="preds_gender_rw",
        run_root=run_root,
    )
    gender_preds_csv = gender_run["preds_csv"]
if not age_preds_csv.exists():
    age_run = train_and_predict(
        name="age",
        csv_path=age_csv,
        weights_col="WEIGHTS_AGE",
        preds_col="preds_age_rw",
        run_root=run_root,
    )
    age_preds_csv = age_run["preds_csv"]


experiment_rows = []
for exp_name, csv_path, pred_col, weight_col in [
    ("baseline", baseline_preds_csv, "preds_baseline", "WEIGHTS"),
    ("gender", gender_preds_csv, "preds_gender_rw", "WEIGHTS_GENDER"),
    ("age", age_preds_csv, "preds_age_rw", "WEIGHTS_AGE"),
]:
    df_pred = pd.read_csv(csv_path)
    df_valid = df_pred[df_pred["train_valid"] == "valid"].copy()

    df_valid["label_bin_eval"] = df_valid["labels"].map({"malade": 1, "sain": 0}).astype(int)
    df_valid["pred_bin_eval"] = df_valid[pred_col].map({"malade": 1, "sain": 0}).astype(int)

    sample_weight = None
    if weight_col in df_valid.columns:
        sample_weight = pd.to_numeric(df_valid[weight_col], errors="coerce").fillna(1.0)

    experiment_rows.append(
        {
            "Expérience": exp_name,
            "Poids": weight_col,
            "Prédictions": pred_col,
            "CSV": str(csv_path),
            "Nb valid": len(df_valid),
            "Accuracy valid": accuracy_score(
                df_valid["label_bin_eval"], df_valid["pred_bin_eval"], sample_weight=sample_weight
            ),
            "Balanced Accuracy valid": balanced_accuracy_score(
                df_valid["label_bin_eval"], df_valid["pred_bin_eval"], sample_weight=sample_weight
            ),
        }
    )

experiment_summary = pd.DataFrame(experiment_rows)
experiment_summary
# Out:
#   Expérience           Poids      Prédictions  \
# 0   baseline         WEIGHTS   preds_baseline
# 1     gender  WEIGHTS_GENDER  preds_gender_rw
# 2        age     WEIGHTS_AGE     preds_age_rw
#
#                                     CSV  Nb valid  Accuracy valid  \
# 0  expe_log/baseline/preds_baseline.csv      1457        0.612903
# 1   expe_log/gender/preds_gender_rw.csv      1457        0.611246
# 2         expe_log/age/preds_age_rw.csv      1457        0.630724
#
#    Balanced Accuracy valid
# 0                 0.611657
# 1                 0.610626
# 2                 0.629797

# %%
### RUN IN COLAB ONLY

confirm = input("Are you sure you are running this on Colab ? Confirm with 'y'")
if confirm != 'y':
    raise ValueError("You must confirm you are running on Colab")
! cp -r ./expe_log/* /content/drive/MyDrive/fairness
# Out:
# Are you sure you are running this on Colab ? Confirm with 'y'y

# %% [markdown]
# Calculons les métriques de performance et de fairness, et comparons-les.

# %%
def build_comparison_table(baseline_valid, rw_valid, protected_eval_col, fairness_weight_col, method_label):
    baseline_metrics = get_metrics(
        y_true=baseline_valid["label_bin_eval"].to_numpy(),
        y_pred=baseline_valid["pred_bin_eval"].to_numpy(),
        prot_attr=baseline_valid[protected_eval_col].to_numpy(),
        pos_label=1,
        sample_weight=baseline_valid["WEIGHTS"].to_numpy(),
    )
    rw_metrics = get_metrics(
        y_true=rw_valid["label_bin_eval"].to_numpy(),
        y_pred=rw_valid["pred_bin_eval"].to_numpy(),
        prot_attr=rw_valid[protected_eval_col].to_numpy(),
        pos_label=1,
        sample_weight=rw_valid[fairness_weight_col].to_numpy(),
    )

    comparison = pd.DataFrame(
        [
            {
                "Method": "Baseline",
                "Accuracy": accuracy_score(
                    baseline_valid["label_bin_eval"],
                    baseline_valid["pred_bin_eval"],
                    sample_weight=baseline_valid["WEIGHTS"],
                ),
                "Balanced Accuracy": balanced_accuracy_score(
                    baseline_valid["label_bin_eval"],
                    baseline_valid["pred_bin_eval"],
                    sample_weight=baseline_valid["WEIGHTS"],
                ),
                "Statistical Parity Diff": baseline_metrics.get("statistical_parity_difference"),
                "Disparate Impact Ratio": baseline_metrics.get("disparate_impact_ratio"),
                "Equal Opportunity Diff": baseline_metrics.get("equal_opportunity_difference"),
                "Average Odds Diff": baseline_metrics.get("average_odds_difference"),
            },
            {
                "Method": method_label,
                "Accuracy": accuracy_score(
                    rw_valid["label_bin_eval"],
                    rw_valid["pred_bin_eval"],
                    sample_weight=rw_valid["WEIGHTS"],
                ),
                "Balanced Accuracy": balanced_accuracy_score(
                    rw_valid["label_bin_eval"],
                    rw_valid["pred_bin_eval"],
                    sample_weight=rw_valid["WEIGHTS"],
                ),
                "Statistical Parity Diff": rw_metrics.get("statistical_parity_difference"),
                "Disparate Impact Ratio": rw_metrics.get("disparate_impact_ratio"),
                "Equal Opportunity Diff": rw_metrics.get("equal_opportunity_difference"),
                "Average Odds Diff": rw_metrics.get("average_odds_difference"),
            },
        ]
    )
    return comparison, baseline_metrics, rw_metrics

# %%
baseline_results = pd.read_csv(baseline_preds_csv)
gender_results = pd.read_csv(gender_preds_csv)
age_results = pd.read_csv(age_preds_csv)

baseline_valid = baseline_results[baseline_results["train_valid"] == "valid"].copy()
gender_valid = gender_results[gender_results["train_valid"] == "valid"].copy()
age_valid = age_results[age_results["train_valid"] == "valid"].copy()

for df_eval, pred_col in [
    (baseline_valid, "preds_baseline"),
    (gender_valid, "preds_gender_rw"),
    (age_valid, "preds_age_rw"),
]:
    df_eval["label_bin_eval"] = df_eval["labels"].map({"malade": 1, "sain": 0}).astype(int)
    df_eval["pred_bin_eval"] = df_eval[pred_col].map({"malade": 1, "sain": 0}).astype(int)
    df_eval["gender_bin_eval"] = (df_eval["Patient Gender"] == "M").astype(int)
    df_eval["age_bin_eval"] = (df_eval["Patient Age"] >= 60).astype(int)
    for weight_col in ["WEIGHTS", "WEIGHTS_GENDER", "WEIGHTS_AGE"]:
        if weight_col in df_eval.columns:
            df_eval[weight_col] = pd.to_numeric(df_eval[weight_col], errors="coerce").fillna(1.0)

assert "preds_baseline" in baseline_valid.columns
assert "preds_gender_rw" in gender_valid.columns
assert "preds_age_rw" in age_valid.columns
assert len(baseline_valid) == len(gender_valid) == len(age_valid)

comparison_gender, baseline_gender_metrics, gender_rw_metrics = build_comparison_table(
    baseline_valid=baseline_valid,
    rw_valid=gender_valid,
    protected_eval_col="gender_bin_eval",
    fairness_weight_col="WEIGHTS_GENDER",
    method_label="Reweighing Gender",
)
display(comparison_gender.round(4))



comparison_age, baseline_age_metrics, age_rw_metrics = build_comparison_table(
    baseline_valid=baseline_valid,
    rw_valid=age_valid,
    protected_eval_col="age_bin_eval",
    fairness_weight_col="WEIGHTS_AGE",
    method_label="Reweighing Age",
)
display(comparison_age.round(4))
# Out:
#               Method  Accuracy  Balanced Accuracy  Statistical Parity Diff  \
# 0           Baseline    0.6129             0.6117                   0.0256
# 1  Reweighing Gender    0.6102             0.6094                   0.1732
#
#    Disparate Impact Ratio  Equal Opportunity Diff  Average Odds Diff
# 0                  1.0591                 -0.0286             0.0134
# 1                  1.4509                  0.1453             0.1592
#            Method  Accuracy  Balanced Accuracy  Statistical Parity Diff  \
# 0        Baseline    0.6129             0.6117                  -0.1320
# 1  Reweighing Age    0.6342             0.6324                  -0.1256
#
#    Disparate Impact Ratio  Equal Opportunity Diff  Average Odds Diff
# 0                  0.7610                 -0.0399            -0.1134
# 1                  0.7617                 -0.0732            -0.1129

# %% [markdown]
# ## Analysis

# %% [markdown]
# Après application du reweighting avec les attributs sensibles gender et age, on observe dans les deux cas une amélioration de l’accuracy. Le reweighting basé sur le genre conduit à une amélioration plus marquée des métriques d’équité. Pour l’âge, les métriques d’équité s’améliorent également, mais de manière plus limitée.

# %% [markdown]
# En conclusion, les résultats montrent que la méthode de reweighting permet d’améliorer à la fois les performances et les métriques de fairness pour les deux attributs sensibles. Cependant, l’amélioration est nettement plus marquée pour le genre, dont les métriques se rapprochent presque des valeurs idéales après reweighting. En revanche, bien que le reweighting appliqué à l’âge réduise le biais initial, les métriques de fairness restent plus éloignées des valeurs souhaitées. Cela suggère que le biais lié à l’âge est plus complexe à corriger et qu’une simple méthode de reweighting ne suffit pas à le atténuer complètement dans notre cas.

# %% [markdown]
# ---
# # 3. Post-processing
#
# ## Introduction
#
# Dans la section précédente, nous avons appliqué des méthodes de **pre-processing** (Reweighing) pour réduire les biais pendant l'entraînement du ResNet18. Ces méthodes agissent en modifiant les poids des exemples d'entraînement
#
# Le **post-processing** propose une approche complémentaire : corriger les **prédictions du modèle déjà entraîné**, sans le réentraîner. C'est particulièrement utile dans notre cas pour :
# - tester rapidement plusieurs stratégies de correction,
# - combiner pré- et post-processing sur les mêmes prédictions.
#
# **Contrainte spécifique à notre modèle** : le ResNet18 fourni via `train_classifieur.py` produit uniquement des **labels discrets** (`malade` / `sain`) dans le CSV de prédictions, sans score de probabilité. Deux méthodes de post-processing nécessitent idéalement des scores de probabilité :
# - Le **Reject-Option Classification (ROC)** (Kamiran et al., 2012)
# - Le **Calibrated Equalized Odds** (Hardt et al., 2016)
#
# Nous gérons cette contrainte en deux temps :
# 1. Si une colonne `proba_malade` est présente dans le CSV (après modification de `train_classifieur.py`), elle est utilisée en priorité.
# 2. Sinon, on utilise les **labels binaires (0/1) comme approximation de scores**. Cela limite la précision de la recherche de seuil, mais permet tout de même d'appliquer et de comparer les méthodes.
#
# **Plan de cette section :**
# 1. Chargement des prédictions et fonctions utilitaires
# 2. Méthode 1 — Reject-Option Classification (ROC)
# 3. Méthode 2 — Calibrated Equalized Odds
# 4. Combinaisons pre-processing + post-processing
# 5. Tableau récapitulatif et visualisation
# 6. Analyse et conclusion

# %% [markdown]
# ## 3.1 Imports et chargement des prédictions

# %%
import numpy as np
import pandas as pd
import warnings
from pathlib import Path
from IPython.display import display
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action="ignore", category=UserWarning)

from sklearn.metrics import accuracy_score, balanced_accuracy_score
from aif360.sklearn.metrics import (
    statistical_parity_difference,
    disparate_impact_ratio,
    equal_opportunity_difference,
    average_odds_difference,
)
from aif360.metrics import BinaryLabelDatasetMetric, ClassificationMetric
from aif360.datasets import BinaryLabelDataset
from aif360.algorithms.postprocessing import (
    RejectOptionClassification,
    CalibratedEqOddsPostprocessing,
    EqOddsPostprocessing,
)

# %%
# --- Chemins vers les CSVs produits en section 2 ---
run_root          = Path("./expe_log")
baseline_preds_csv = run_root / "baseline" / "preds_baseline.csv"
gender_preds_csv   = run_root / "gender"   / "preds_gender_rw.csv"
age_preds_csv      = run_root / "age"      / "preds_age_rw.csv"

# --- Chargement du CSV baseline ---
baseline_results = pd.read_csv(baseline_preds_csv)
baseline_train = baseline_results[baseline_results["train_valid"] == "train"].copy().reset_index(drop=True)
baseline_valid = baseline_results[baseline_results["train_valid"] == "valid"].copy().reset_index(drop=True)

from scipy.special import softmax

# 1. On récupère les colonnes de logits
# logit0 = sain et logit1 = malade d'après le label_encoder
logits_cols = ['preds_baseline_logit0', 'preds_baseline_logit1']

# 2. On extrait les valeurs sous forme de tableau numpy
logits_array = baseline_valid[logits_cols].to_numpy()

# 3. On applique le softmax sur la dimension 1 (sur chaque ligne)
probabilites = softmax(logits_array, axis=1)

# 4. On crée la  colonne proba_malade
# (On prend l'index 1 si c'est bien la classe "malade")
baseline_valid['proba_malade'] = probabilites[:, 0]

# Encodage binaire commun
for split_df in [baseline_train, baseline_valid]:
    split_df["label_bin"]  = split_df["labels"].map({"malade": 1, "sain": 0}).astype(int)
    split_df["pred_bin"]   = split_df["preds_baseline"].map({"malade": 1, "sain": 0}).astype(int)
    split_df["gender_bin"] = (split_df["Patient Gender"] == "M").astype(int)
    split_df["age_bin"]    = (split_df["Patient Age"] >= 60).astype(int)
    split_df["WEIGHTS"]    = pd.to_numeric(split_df["WEIGHTS"], errors="coerce").fillna(1.0)

# Détection des scores de probabilité
SCORE_COL = "proba_malade" if "proba_malade" in baseline_valid.columns else None
if SCORE_COL:
    print(f" Colonne de scores '{SCORE_COL}' trouvée — utilisation des probabilités.")
else:
    print("  Pas de colonne 'proba_malade' et approximation avec les labels binaires (0/1).")

print(f"\nTrain : {len(baseline_train)} images | Validation : {len(baseline_valid)} images")
# Out:
#  Colonne de scores 'proba_malade' trouvée — utilisation des probabilités.
#
# Train : 4135 images | Validation : 1457 images

# %% [markdown]
# ## 3.2 Fonctions utilitaires
#
# On réutilise le même `get_metrics` que dans la section pre-processing, et on ajoute des fonctions de conversion pour l'API AIF360.

# %%
def make_aif360_dataset(df, label_col, sensitive_col, score_col=None):
    """
    Crée un BinaryLabelDataset AIF360 à partir d'un DataFrame.
    Si score_col est fourni (scores de probabilité), il est stocké dans .scores.
    Sinon, les labels binaires servent d'approximation de scores (0 ou 1).
    """
    df_aif = df[[label_col, sensitive_col]].copy().reset_index(drop=True)
    dataset = BinaryLabelDataset(
        df=df_aif,
        label_names=[label_col],
        protected_attribute_names=[sensitive_col],
        favorable_label=1,
        unfavorable_label=0,
    )
    if score_col and score_col in df.columns:
        dataset.scores = df[score_col].to_numpy().reshape(-1, 1).astype(float)
    else:
        dataset.scores = df[label_col].to_numpy().reshape(-1, 1).astype(float)
    return dataset


def compute_metrics_row(y_true, y_pred, prot_attr, weights, label):
    """Retourne un dict de métriques de performance + fairness."""
    return {
        "Méthode":             label,
        "Accuracy":            round(accuracy_score(y_true, y_pred, sample_weight=weights), 4),
        "Balanced Acc.": round(balanced_accuracy_score(y_true, y_pred, sample_weight=weights), 4),
        "Stat. Parity Diff":   round(statistical_parity_difference(y_true, y_pred, prot_attr=prot_attr, pos_label=1), 4),
        "Disparate Impact":    round(disparate_impact_ratio(y_true, y_pred, prot_attr=prot_attr, pos_label=1), 4),
        "Equal Opp. Diff":     round(equal_opportunity_difference(y_true, y_pred, prot_attr=prot_attr, pos_label=1), 4),
        "Avg Odds Diff":       round(average_odds_difference(y_true, y_pred, prot_attr=prot_attr, pos_label=1), 4),
    }


def find_best_threshold(ds_true, ds_pred_scores, unprivileged_groups, privileged_groups, num_thresh=100):
    """
    Recherche du seuil de classification optimal maximisant la balanced accuracy.
    comme en td
    """
    class_thresh_arr = np.linspace(0.01, 0.99, num_thresh)
    ba_arr = np.zeros(num_thresh)
    ds_sweep = ds_true.copy(deepcopy=True)
    ds_sweep.scores = ds_pred_scores.scores.copy()

    for idx, thresh in enumerate(class_thresh_arr):
        fav = ds_sweep.scores > thresh
        ds_sweep.labels[fav]  = ds_sweep.favorable_label
        ds_sweep.labels[~fav] = ds_sweep.unfavorable_label
        cm = ClassificationMetric(
            ds_true, ds_sweep,
            unprivileged_groups=unprivileged_groups,
            privileged_groups=privileged_groups,
        )
        ba_arr[idx] = 0.5 * (cm.true_positive_rate() + cm.true_negative_rate())

    best_thresh = class_thresh_arr[np.argmax(ba_arr)]
    return best_thresh, ba_arr.max()


def apply_threshold(ds_pred, threshold):
    """Applique un seuil de classification sur un BinaryLabelDataset."""
    ds_out = ds_pred.copy(deepcopy=True)
    fav = ds_out.scores > threshold
    ds_out.labels[fav]  = ds_out.favorable_label
    ds_out.labels[~fav] = ds_out.unfavorable_label
    return ds_out

def make_pred_dataset(ds_true, df, pred_col, score_col=None):
    """
    Crée un dataset de prédictions par copie profonde du dataset de vérité terrain.
    Ceci évite les erreurs de métadonnées AIF360 (ValueError: expected to differ only in...).
    """
    ds_pred = ds_true.copy(deepcopy=True)
    # On écrase les labels
    ds_pred.labels = df[pred_col].to_numpy().reshape(-1, 1).astype(float)

    # On écrase les scores
    if score_col and score_col in df.columns:
        ds_pred.scores = df[score_col].to_numpy().reshape(-1, 1).astype(float)
    else:
        ds_pred.scores = ds_pred.labels.copy()

    return ds_pred

print("Fonctions utilitaires prêtes.")
# Out:
# Fonctions utilitaires prêtes.

# %% [markdown]
# ## 3.3 Préparation des datasets AIF360 et recherche des seuils optimaux
#
# On prépare les datasets pour les deux attributs sensibles (**genre** et **âge**), puis on recherche le seuil de classification optimal pour chacun.

# %%
# ============================================================
# GENRE : Hommes (M=1, privilégiés) vs Femmes (F=0, désavantagées)
# ============================================================
SENS_GENDER       = "gender_bin"
PRIV_GENDER       = [{SENS_GENDER: 1}]
UNPRIV_GENDER     = [{SENS_GENDER: 0}]

ds_val_true_G  = make_aif360_dataset(baseline_valid, "label_bin", SENS_GENDER, SCORE_COL)
ds_val_pred_G  = make_pred_dataset(ds_val_true_G, baseline_valid, "pred_bin", SCORE_COL) #
ds_train_true_G = make_aif360_dataset(baseline_train, "label_bin", SENS_GENDER, SCORE_COL)
ds_train_pred_G = make_pred_dataset(ds_train_true_G, baseline_train, "pred_bin", SCORE_COL) #

best_thresh_G, best_ba_G = find_best_threshold(ds_val_true_G, ds_val_pred_G, UNPRIV_GENDER, PRIV_GENDER)
ds_val_pred_G_thresh = apply_threshold(ds_val_pred_G, best_thresh_G)
print(f"Genre  — Seuil optimal : {best_thresh_G:.4f} | Balanced Accuracy : {best_ba_G:.4f}")

# ============================================================
# ÂGE : < 60 ans (0, privilégiés) vs ≥ 60 ans (1, désavantagés)
# ============================================================
SENS_AGE          = "age_bin"
PRIV_AGE          = [{SENS_AGE: 0}]
UNPRIV_AGE        = [{SENS_AGE: 1}]

ds_val_true_A  = make_aif360_dataset(baseline_valid, "label_bin", SENS_AGE, SCORE_COL)
ds_val_pred_A  = make_pred_dataset(ds_val_true_A, baseline_valid, "pred_bin", SCORE_COL) #
ds_train_true_A = make_aif360_dataset(baseline_train, "label_bin", SENS_AGE, SCORE_COL)
ds_train_pred_A = make_pred_dataset(ds_train_true_A, baseline_train, "pred_bin", SCORE_COL) #

best_thresh_A, best_ba_A = find_best_threshold(ds_val_true_A, ds_val_pred_A, UNPRIV_AGE, PRIV_AGE)
ds_val_pred_A_thresh = apply_threshold(ds_val_pred_A, best_thresh_A)
print(f"Âge    — Seuil optimal : {best_thresh_A:.4f} | Balanced Accuracy : {best_ba_A:.4f}")

# Raccourcis pour les métriques
y_true   = baseline_valid["label_bin"].to_numpy()
y_pred_baseline = baseline_valid["pred_bin"].to_numpy()
weights  = baseline_valid["WEIGHTS"].to_numpy()
prot_G   = baseline_valid[SENS_GENDER].to_numpy()
prot_A   = baseline_valid[SENS_AGE].to_numpy()
# Out:
# Genre  — Seuil optimal : 0.4258 | Balanced Accuracy : 0.6203
# Âge    — Seuil optimal : 0.4258 | Balanced Accuracy : 0.6203

# %% [markdown]
# ## 3.4 Méthode 1 : Reject-Option Classification (ROC)
#
#
# ### Principe
#
# Le ROC définit une **région critique** autour du seuil de décision avec un paramètre  θ
#
# Dans cette zone d'incertitude :
# - groupe **désavantagé** → label favorable
# - groupe **privilégié** → label défavorable
#
# Hors de cette zone, la règle de décision standard s'applique. AIF360 optimise conjointement θ et le seuil de classification sous une contrainte de Statistical Parity.

# %%
ROC_PARAMS = dict(
    low_class_thresh=0.01, high_class_thresh=0.99,
    num_class_thresh=100,  num_ROC_margin=50,
    metric_name="Statistical parity difference",
    metric_ub=0.05, metric_lb=-0.05,
)

#  ROC sur baseline — Genre
roc_G = RejectOptionClassification(privileged_groups=PRIV_GENDER, unprivileged_groups=UNPRIV_GENDER, **ROC_PARAMS)
roc_G.fit(ds_val_true_G, ds_val_pred_G_thresh)
y_pred_roc_G = roc_G.predict(ds_val_pred_G_thresh).labels[:, 0].astype(int)

print(f"ROC Genre  — seuil classif : {roc_G.classification_threshold:.4f} | marge θ : {roc_G.ROC_margin:.4f}")

#  ROC sur baseline — Age
roc_A = RejectOptionClassification(privileged_groups=PRIV_AGE, unprivileged_groups=UNPRIV_AGE, **ROC_PARAMS)
roc_A.fit(ds_val_true_A, ds_val_pred_A_thresh)
y_pred_roc_A = roc_A.predict(ds_val_pred_A_thresh).labels[:, 0].astype(int)

print(f"ROC Âge    — seuil classif : {roc_A.classification_threshold:.4f} | marge θ : {roc_A.ROC_margin:.4f}")
# Out:
# ROC Genre  — seuil classif : 0.4357 | marge θ : 0.0089
# ROC Âge    — seuil classif : 0.6930 | marge θ : 0.0000

# %% [markdown]
# ## 3.5 Méthode 2 : Calibrated Equalized Odds
#
# ### Principe
#
# L'equalized odds impose que le TPR et le FPR soient identiques entre groupes
#
# Le Calibrated EqOdds ajuste les prédictions via une **randomisation** optimisant un coût sur les taux d'erreur. Le paramètre `cost_constraint` détermine ce qui est optimisé :
# - `"fnr"` : minimise les faux négatifs différentiels → **le plus adapté au contexte médical** (s'assurer que les deux groupes ont autant de chances d'être correctement diagnostiqués malades)
# - `"fpr"` : minimise les faux positifs différentiels
# - `"weighted"` : combinaison des deux

# %%
# On teste les trois contraintes pour illustrer leur effet
ceqodds_results_G = {}
ceqodds_results_A = {}

for cost in ["fnr", "fpr", "weighted"]:
    #  Genre
    cpp_g = CalibratedEqOddsPostprocessing(
        privileged_groups=PRIV_GENDER, unprivileged_groups=UNPRIV_GENDER,
        cost_constraint=cost, seed=42,
    )
    cpp_g.fit(ds_val_true_G, ds_val_pred_G_thresh)
    ceqodds_results_G[cost] = cpp_g.predict(ds_val_pred_G_thresh).labels[:, 0].astype(int)

    #  Âge
    cpp_a = CalibratedEqOddsPostprocessing(
        privileged_groups=PRIV_AGE, unprivileged_groups=UNPRIV_AGE,
        cost_constraint=cost, seed=42,
    )
    cpp_a.fit(ds_val_true_A, ds_val_pred_A_thresh)
    ceqodds_results_A[cost] = cpp_a.predict(ds_val_pred_A_thresh).labels[:, 0].astype(int)

print("Calibrated EqOdds appliqué pour les trois contraintes (fnr / fpr / weighted) sur genre et âge.")
# Out:
# Calibrated EqOdds appliqué pour les trois contraintes (fnr / fpr / weighted) sur genre et âge.

# %% [markdown]
# ## 3.6 Combinaisons Pre-processing + Post-processing
#
# On applique maintenant les méthodes de post-processing sur les prédictions des **modèles entraînés avec Reweighing** (section pre-processing). L'idée est de cumuler les effets des deux types de correction.

# %%
def load_rw_predictions(csv_path, pred_col, sensitive_col_fn, sensitive_col_name):
    """
    Charge les prédictions d'un modèle Reweighed et retourne
    le dataframe de validation ainsi que les datasets AIF360.
    """
    df = pd.read_csv(csv_path)
    valid = df[df["train_valid"] == "valid"].copy().reset_index(drop=True)
    valid["label_bin"]      = valid["labels"].map({"malade": 1, "sain": 0}).astype(int)
    valid["pred_bin"]       = valid[pred_col].map({"malade": 1, "sain": 0}).astype(int)
    valid[sensitive_col_name] = sensitive_col_fn(valid)

    from scipy.special import softmax
    # On reconstitue le nom des colonnes de logits
    logits_cols = [f'{pred_col}_logit0', f'{pred_col}_logit1']

    # Si les logits sont bien là, on calcule les probabilités
    if logits_cols[0] in valid.columns:
        logits_array = valid[logits_cols].to_numpy()
        probabilites = softmax(logits_array, axis=1)
        valid['proba_malade'] = probabilites[:, 0] # On prend la classe 0 (malade)

    score_col = "proba_malade" if "proba_malade" in valid.columns else None
    return valid, score_col


#  Chargement Reweighing Genre
rw_gender_available = False
if gender_preds_csv.exists():
    rw_G_valid, score_rw_G = load_rw_predictions(
        gender_preds_csv, "preds_gender_rw",
        lambda d: (d["Patient Gender"] == "M").astype(int), SENS_GENDER
    )
    rw_G_valid["WEIGHTS_GENDER"] = pd.to_numeric(rw_G_valid["WEIGHTS_GENDER"], errors="coerce").fillna(1.0)
    rw_gender_available = True
    print(f"Reweighing Genre chargé ({len(rw_G_valid)} images valides)")
else:
    print(" Prédictions Reweighing Genre introuvables.")

# Chargement Reweighing Âge
rw_age_available = False
if age_preds_csv.exists():
    rw_A_valid, score_rw_A = load_rw_predictions(
        age_preds_csv, "preds_age_rw",
        lambda d: (d["Patient Age"] >= 60).astype(int), SENS_AGE
    )
    rw_A_valid["WEIGHTS_AGE"] = pd.to_numeric(rw_A_valid["WEIGHTS_AGE"], errors="coerce").fillna(1.0)
    rw_age_available = True
    print(f" Reweighing Âge chargé ({len(rw_A_valid)} images valides)")
else:
    print(" Prédictions Reweighing Âge introuvables.")
# Out:
# Reweighing Genre chargé (1457 images valides)
#  Reweighing Âge chargé (1457 images valides)

# %%
# ---- Combinaison RW_Genre + post-processing ----
combo_roc_G = None
combo_ceqodds_G = None

if rw_gender_available:
    ds_rw_true_G = make_aif360_dataset(rw_G_valid, "label_bin", SENS_GENDER, score_rw_G)
    ds_rw_pred_G = make_pred_dataset(ds_rw_true_G, rw_G_valid, "pred_bin", score_rw_G) #

    # Seuil optimal pour ce modèle
    best_thresh_rw_G, _ = find_best_threshold(ds_rw_true_G, ds_rw_pred_G, UNPRIV_GENDER, PRIV_GENDER)
    ds_rw_pred_G_thresh = apply_threshold(ds_rw_pred_G, best_thresh_rw_G)

    # ROC
    roc_rw_G = RejectOptionClassification(privileged_groups=PRIV_GENDER, unprivileged_groups=UNPRIV_GENDER, **ROC_PARAMS)
    roc_rw_G.fit(ds_rw_true_G, ds_rw_pred_G_thresh)
    combo_roc_G = roc_rw_G.predict(ds_rw_pred_G_thresh).labels[:, 0].astype(int)

    # Calibrated EqOdds (fnr)
    cpp_rw_G = CalibratedEqOddsPostprocessing(
        privileged_groups=PRIV_GENDER, unprivileged_groups=UNPRIV_GENDER,
        cost_constraint="fnr", seed=42,
    )
    cpp_rw_G.fit(ds_rw_true_G, ds_rw_pred_G_thresh)
    combo_ceqodds_G = cpp_rw_G.predict(ds_rw_pred_G_thresh).labels[:, 0].astype(int)

    print(f"RW+ROC Genre        | θ={roc_rw_G.ROC_margin:.4f}")
    print(f"RW+CEqOdds(fnr) Genre | combinaison appliquée")
# Out:
# RW+ROC Genre        | θ=0.0030
# RW+CEqOdds(fnr) Genre | combinaison appliquée

# %%
# ---- Combinaison RW_Âge + post-processing ----
combo_roc_A = None
combo_ceqodds_A = None

if rw_age_available:
    ds_rw_true_A = make_aif360_dataset(rw_A_valid, "label_bin", SENS_AGE, score_rw_A)
    ds_rw_pred_A = make_pred_dataset(ds_rw_true_A, rw_A_valid, "pred_bin", score_rw_A)

    best_thresh_rw_A, _ = find_best_threshold(ds_rw_true_A, ds_rw_pred_A, UNPRIV_AGE, PRIV_AGE)
    ds_rw_pred_A_thresh = apply_threshold(ds_rw_pred_A, best_thresh_rw_A)

    # ROC
    roc_rw_A = RejectOptionClassification(privileged_groups=PRIV_AGE, unprivileged_groups=UNPRIV_AGE, **ROC_PARAMS)
    roc_rw_A.fit(ds_rw_true_A, ds_rw_pred_A_thresh)
    combo_roc_A = roc_rw_A.predict(ds_rw_pred_A_thresh).labels[:, 0].astype(int)

    # Calibrated EqOdds (fnr)
    cpp_rw_A = CalibratedEqOddsPostprocessing(
        privileged_groups=PRIV_AGE, unprivileged_groups=UNPRIV_AGE,
        cost_constraint="fnr", seed=42,
    )
    cpp_rw_A.fit(ds_rw_true_A, ds_rw_pred_A_thresh)
    combo_ceqodds_A = cpp_rw_A.predict(ds_rw_pred_A_thresh).labels[:, 0].astype(int)

    print(f"RW+ROC Âge          — θ={roc_rw_A.ROC_margin:.4f}")
    print(f"RW+CEqOdds(fnr) Âge — combinaison appliquée")
# Out:
# RW+ROC Âge          — θ=0.0073
# RW+CEqOdds(fnr) Âge — combinaison appliquée

# %% [markdown]
# ## 3.7 Tableau récapitulatif de toutes les méthodes

# %%
def build_table(rows):
    return pd.DataFrame(rows).set_index("Méthode")


# ============================================================
# TABLE GENRE
# ============================================================
rows_G = [
    compute_metrics_row(y_true, y_pred_baseline, prot_G, weights, "Baseline"),
    compute_metrics_row(y_true, y_pred_roc_G,    prot_G, weights, "ROC (post)"),
    compute_metrics_row(y_true, ceqodds_results_G["fnr"], prot_G, weights, "CEqOdds fnr (post)"),
    compute_metrics_row(y_true, ceqodds_results_G["fpr"], prot_G, weights, "CEqOdds fpr (post)"),
    compute_metrics_row(y_true, ceqodds_results_G["weighted"], prot_G, weights, "CEqOdds weighted (post)"),
]

if rw_gender_available:
    rw_G_y_true = rw_G_valid["label_bin"].to_numpy()
    rw_G_prot   = rw_G_valid[SENS_GENDER].to_numpy()
    rw_G_w      = rw_G_valid["WEIGHTS_GENDER"].to_numpy()
    rows_G.insert(1, compute_metrics_row(rw_G_y_true, rw_G_valid["pred_bin"].to_numpy(), rw_G_prot, rw_G_w, "Reweighing (pre)"))
    if combo_roc_G is not None:
        rows_G.append(compute_metrics_row(rw_G_y_true, combo_roc_G,    rw_G_prot, rw_G_w, "RW + ROC"))
        rows_G.append(compute_metrics_row(rw_G_y_true, combo_ceqodds_G, rw_G_prot, rw_G_w, "RW + CEqOdds fnr"))

df_G = build_table(rows_G)

# ============================================================
# TABLE ÂGE
# ============================================================
rows_A = [
    compute_metrics_row(y_true, y_pred_baseline, prot_A, weights, "Baseline"),
    compute_metrics_row(y_true, y_pred_roc_A,    prot_A, weights, "ROC (post)"),
    compute_metrics_row(y_true, ceqodds_results_A["fnr"], prot_A, weights, "CEqOdds fnr (post)"),
    compute_metrics_row(y_true, ceqodds_results_A["fpr"], prot_A, weights, "CEqOdds fpr (post)"),
    compute_metrics_row(y_true, ceqodds_results_A["weighted"], prot_A, weights, "CEqOdds weighted (post)"),
]

if rw_age_available:
    rw_A_y_true = rw_A_valid["label_bin"].to_numpy()
    rw_A_prot   = rw_A_valid[SENS_AGE].to_numpy()
    rw_A_w      = rw_A_valid["WEIGHTS_AGE"].to_numpy()
    rows_A.insert(1, compute_metrics_row(rw_A_y_true, rw_A_valid["pred_bin"].to_numpy(), rw_A_prot, rw_A_w, "Reweighing (pre)"))
    if combo_roc_A is not None:
        rows_A.append(compute_metrics_row(rw_A_y_true, combo_roc_A,    rw_A_prot, rw_A_w, "RW + ROC"))
        rows_A.append(compute_metrics_row(rw_A_y_true, combo_ceqodds_A, rw_A_prot, rw_A_w, "RW + CEqOdds fnr"))

df_A = build_table(rows_A)

print("===== Attribut sensible : Genre (H vs F) =====")
display(df_G)
print("\n===== Attribut sensible : Âge (< 60 vs ≥ 60) =====")
display(df_A)
# Out:
# ===== Attribut sensible : Genre (H vs F) =====
#                          Accuracy  Balanced Acc.  Stat. Parity Diff  \
# Méthode
# Baseline                   0.6129         0.6117             0.0256
# Reweighing (pre)           0.6112         0.6106             0.1701
# ROC (post)                 0.6225         0.6233             0.0290
# CEqOdds fnr (post)         0.5944         0.5911             0.1911
# CEqOdds fpr (post)         0.6005         0.5979             0.1368
# CEqOdds weighted (post)    0.5937         0.5904             0.1898
# RW + ROC                   0.5105         0.5201             0.0496
# RW + CEqOdds fnr           0.5741         0.5779             0.6146
#
#                          Disparate Impact  Equal Opp. Diff  Avg Odds Diff
# Méthode
# Baseline                           1.0591          -0.0286         0.0134
# Reweighing (pre)                   1.4414           0.1453         0.1592
# ROC (post)                         1.0562          -0.0175         0.0159
# CEqOdds fnr (post)                 1.7144           0.1886         0.1825
# CEqOdds fpr (post)                 1.4251           0.1171         0.1270
# CEqOdds weighted (post)            1.7060           0.1886         0.1813
# RW + ROC                           1.0528           0.0314         0.0474
# RW + CEqOdds fnr                   2.5945           0.4943         0.6064
# ===== Attribut sensible : Âge (< 60 vs ≥ 60) =====
#                          Accuracy  Balanced Acc.  Stat. Parity Diff  \
# Méthode
# Baseline                   0.6129         0.6117            -0.1320
# Reweighing (pre)           0.6307         0.6298            -0.1421
# ROC (post)                 0.5614         0.5528            -0.0411
# CEqOdds fnr (post)         0.6129         0.6117            -0.1320
# CEqOdds fpr (post)         0.5415         0.5321            -0.5523
# CEqOdds weighted (post)    0.5690         0.5633            -0.3608
# RW + ROC                   0.5312         0.5367            -0.0487
# RW + CEqOdds fnr           0.6307         0.6298            -0.1421
#
#                          Disparate Impact  Equal Opp. Diff  Avg Odds Diff
# Méthode
# Baseline                           0.7610          -0.0399        -0.1134
# Reweighing (pre)                   0.7357          -0.0732        -0.1129
# ROC (post)                         0.7629          -0.0061        -0.0305
# CEqOdds fnr (post)                 0.7610          -0.0399        -0.1134
# CEqOdds fpr (post)                 0.0000          -0.5904        -0.5429
# CEqOdds weighted (post)            0.3467          -0.3463        -0.3477
# RW + ROC                           0.9502          -0.0058        -0.0445
# RW + CEqOdds fnr                   0.7357          -0.0732        -0.1129

# %% [markdown]
# ## 3.8 Visualisation comparative

# %%
COLORS = ["#1565C0", "#2E7D32", "#F57F17", "#AD1457", "#6A1B9A", "#00838F", "#BF360C"]

def plot_fairness_comparison(df_compare, title, ax_acc, ax_fair):
    methods = df_compare.index.tolist()
    x = np.arange(len(methods))
    w = 0.35

    # --- Accuracy ---
    ax_acc.bar(x - w/2, df_compare["Accuracy"],       w, label="Accuracy",       color=COLORS[0], alpha=0.85, edgecolor="black", linewidth=0.5)
    ax_acc.bar(x + w/2, df_compare["Balanced Acc."],   w, label="Balanced Acc.",  color=COLORS[1], alpha=0.85, edgecolor="black", linewidth=0.5)
    ax_acc.set_xticks(x)
    ax_acc.set_xticklabels(methods, rotation=30, ha="right", fontsize=8)
    ax_acc.set_ylim(0.45, 1.0)
    ax_acc.set_ylabel("Score")
    ax_acc.set_title(f"Performance – {title}", fontsize=10, fontweight="bold")
    ax_acc.legend(fontsize=8)
    ax_acc.grid(axis="y", linestyle=":", alpha=0.4)

    # --- Fairness ---
    fair_cols = ["Stat. Parity Diff", "Equal Opp. Diff", "Avg Odds Diff"]
    wf = 0.8 / len(fair_cols)
    for j, col in enumerate(fair_cols):
        ax_fair.bar(x + (j - 1) * wf, df_compare[col], wf,
                    label=col, color=COLORS[j+2], alpha=0.85, edgecolor="black", linewidth=0.5)
    ax_fair.axhline(0, color="black", linewidth=1.2, linestyle="--", label="Idéal")
    ax_fair.set_xticks(x)
    ax_fair.set_xticklabels(methods, rotation=30, ha="right", fontsize=8)
    ax_fair.set_ylabel("Valeur (idéal = 0)")
    ax_fair.set_title(f"Fairness – {title}", fontsize=10, fontweight="bold")
    ax_fair.legend(fontsize=8)
    ax_fair.grid(axis="y", linestyle=":", alpha=0.4)


fig, axes = plt.subplots(2, 2, figsize=(18, 11))
plot_fairness_comparison(df_G, "Genre (H vs F)",   axes[0][0], axes[0][1])
plot_fairness_comparison(df_A, "Âge (< 60 vs ≥ 60)", axes[1][0], axes[1][1])

fig.suptitle("Comparaison de toutes les méthodes de mitigation — Post-processing",
             fontsize=13, fontweight="bold", y=1.01)
plt.tight_layout()
plt.savefig("postprocessing_comparison.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# Analyse:
#
# <u>Le cas du genre </u>
#
# Les trois barres de la Baseline sont minuscules, quasiment sur la ligne du zéro. Le modèle de base ne faisait pratiquement aucune discrimination entre hommes et femmes.
# Le Reweighing crée du biais : L'application du Reweighing (pre) fait monter les barres vers +0.15. Au lieu d'améliorer les choses, la modification des poids à l'entraînement a artificiellement déséquilibré le modèle.
#
# Regardons la barre RW + ROC. Le ROC est venu s'appliquer par-dessus le Reweighing. Il a remarqué le biais créé par le Reweighing et a réussi à le corriger (les barres Fairness redescendent vers 0.05). Mais si on regarde le graphique de l'accuracy: Pour rattraper les erreurs du Reweighing, le RW + ROC a dû sacrifier énormément de prédictions : l'Accuracy s'effondre  autour de 50 %. Donc Combiner deux algorithmes sur un attribut déjà neutre détruit complètement la capacité prédictive du modèle.
#
# <u>Le cas de l'âge </u>
#
# Ici, c'est différent car il y a un vrai biais à l'origine. Sur le graphique en bas à droite, la Baseline présente des barres nettement négatives (autour de -0.12). Le modèle original se trompe plus souvent au détriment des patients seniors (≥ 60 ans).
#
#  Le Reweighing (pre) ne parvient pas à corriger ce biais (les barres restent très négatives), bien qu'il améliore légèrement l'Accuracy. Changer les poids à l'entraînement n'a pas suffi à effacer les préjugés du réseau de neurones.
#
# Le ROC réarrange tout ça. Elles remontent presque parfaitement vers la ligne du zéro idéal avec une accuracy correcte. En jouant intelligemment avec les seuils de probabilité après l'entraînement, le ROC a réussi à rétablir l'équité pour les seniors.
#
# Regardons maintenant les barres de fairness pour RW + ROC : elles sont à peu près au même niveau que ROC (post) (autour de -0.05). L'équité n'est pas meilleure. Par contre, sur le graphique de Performance : l'Accuracy du RW + ROC a chuté encore plus bas .
# On peut retenir que Le Reweighing et le ROC ne s'additionnent pas de manière magique. Leurs effets entrent en conflit. Le ROC doit "lutter" contre les poids modifiés du Reweighing, ce qui dégrade la performance sans apporter de gain supplémentaire sur l'équité.
